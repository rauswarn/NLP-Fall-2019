# %%
import pandas as pd
import re 
from nltk.util import ngrams
import nltk
import copy

# %%
f = open('trump_tweets.txt')

ftxt = f.read()

# %%
from nltk.tokenize import sent_tokenize

fsent = sent_tokenize(ftxt)

# %%
len(fsent)
# Out:
# 16493

# %%
split_size = (int)(len(fsent)*0.8)
train = fsent[0:split_size]
test = fsent[split_size:]
print(len(train), len(test))
# Out:
# 13194 3299

# %%
tokensum = []

for each in train:    
    s = each.lower()
    s = re.sub(r'[^a-zA-Z0-9\s]', ' ', each)
    tokens = [token for token in each.split(" ") if token != ""]
    
    for every in tokens:
        tokensum.append(every)

# %%
tokensum
# Out:
# ['SPEECH',
#  '1\n\n\n...Thank',
#  'you',
#  'so',
#  'much.',
#  "That's",
#  'so',
#  'nice.',
#  "Isn't",
#  'he',
#  'a',
#  'great',
#  'guy.',
#  'He',
#  "doesn't",
#  'get',
#  'a',
#  'fair',
#  'press;',
#  'he',
#  "doesn't",
#  'get',
#  'it.',
#  "It's",
#  'just',
#  'not',
#  'fair.',
#  'And',
#  'I',
#  'have',
#  'to',
#  'tell',
#  'you',
#  "I'm",
#  'here,',
#  'and',
#  'very',
#  'strongly',
#  'here,',
#  'because',
#  'I',
#  'have',
#  'great',
#  'respect',
#  'for',
#  'Steve',
#  'King',
#  'and',
#  'have',
#  'great',
#  'respect',
#  'likewise',
#  'for',
#  'Citizens',
#  'United,',
#  'David',
#  'and',
#  'everybody,',
#  'and',
#  'tremendous',
#  'resect',
#  'for',
#  'the',
#  'Tea',
#  'Party.',
#  'Also,',
#  'also',
#  'the',
#  'people',
#  'of',
#  'Iowa.',
#  'They',
#  'have',
#  'something',
#  'in',
#  'common.',
#  'Hard-working',
#  'people.',
#  'They',
#  'want',
#  'to',
#  'work,',
#  'they',
#  'want',
#  'to',
#  'make',
#  'the',
#  'country',
#  'great.',
#  'I',
#  'love',
#  'the',
#  'people',
#  'of',
#  'Iowa.',
#  'So',
#  "that's",
#  'the',
#  'way',
#  'it',
#  'is.',
#  'Very',
#  'simple.',
#  'With',
#  'that',
#  'said,',
#  'our',
#  'country',
#  'is',
#  'really',
#  'headed',
#  'in',
#  'the',
#  'wrong',
#  'direction',
#  'with',
#  'a',
#  'president',
#  'who',
#  'is',
#  'doing',
#  'an',
#  'absolutely',
#  'terrible',
#  'job.',
#  'The',
#  'world',
#  'is',
#  'collapsing',
#  'around',
#  'us,',
#  'and',
#  'many',
#  'of',
#  'the',
#  'problems',
#  "we've",
#  'caused.',
#  'Our',
#  'president',
#  'is',
#  'either',
#  'grossly',
#  'incompetent,',
#  'a',
#  'word',
#  'that',
#  'more',
#  'and',
#  'more',
#  'people',
#  'are',
#  'using,',
#  'and',
#  'I',
#  'think',
#  'I',
#  'was',
#  'the',
#  'first',
#  'to',
#  'use',
#  'it,',
#  'or',
#  'he',
#  'has',
#  'a',
#  'completely',
#  'different',
#  'agenda',
#  'than',
#  'you',
#  'want',
#  'to',
#  'know',
#  'about,',
#  'which',
#  'could',
#  'be',
#  'possible.',
#  'In',
#  'any',
#  'event,',
#  'Washington',
#  'is',
#  'broken,',
#  'and',
#  'our',
#  'country',
#  'is',
#  'in',
#  'serious',
#  'trouble',
#  'and',
#  'total',
#  'disarray.',
#  'Very',
#  'simple.',
#  'Politicians',
#  'are',
#  'all',
#  'talk,',
#  'no',
#  'action.',
#  'They',
#  'are',
#  'all',
#  'talk',
#  'and',
#  'no',
#  'action.',
#  'And',
#  "it's",
#  'constant;',
#  'it',
#  'never',
#  'ends.',
#  'And',
#  "I'm",
#  'a',
#  'conservative,',
#  'actually',
#  'very',
#  'conservative,',
#  'and',
#  "I'm",
#  'a',
#  'Republican.',
#  'And',
#  "I'm",
#  'very',
#  'disappointed',
#  'by',
#  'our',
#  'Republican',
#  'politicians.',
#  'Because',
#  'they',
#  'let',
#  'the',
#  'president',
#  'get',
#  'away',
#  'with',
#  'absolute',
#  'murder.',
#  'You',
#  'see',
#  'always,',
#  'oh',
#  "we're",
#  'going',
#  'to',
#  'do',
#  'this,',
#  "we're",
#  'going',
#  'to--.',
#  'Nothing',
#  'ever',
#  'happens;',
#  'nothing',
#  'ever',
#  'happens.',
#  'You',
#  'look',
#  'at',
#  'Obamacare.',
#  'A',
#  'total',
#  'catastrophe',
#  'and',
#  'by',
#  'the',
#  'way',
#  'it',
#  'really',
#  'kicks',
#  'in',
#  'in',
#  "'16",
#  'and',
#  'it',
#  'is',
#  'going',
#  'to',
#  'be',
#  'a',
#  'disaster.',
#  'People',
#  'are',
#  'closing',
#  'up',
#  'shops.',
#  'Doctors',
#  'are',
#  'quitting',
#  'the',
#  'business.',
#  'I',
#  'have',
#  'a',
#  'friend',
#  'of',
#  'mine',
#  "who's",
#  'a',
#  'doctor,',
#  'a',
#  'very',
#  'good',
#  'doctor,',
#  'a',
#  'very',
#  'successful',
#  'guy.',
#  'He',
#  'said,',
#  'I',
#  'have',
#  'more',
#  'accountants',
#  'than',
#  'I',
#  'have',
#  'patients.',
#  'And',
#  'he',
#  'needs',
#  'because',
#  'it',
#  'is',
#  'so',
#  'complicated',
#  'and',
#  'so',
#  'terrible',
#  'and',
#  "he's",
#  'never',
#  'had',
#  'that',
#  'before',
#  'and',
#  "he's",
#  'going',
#  'to',
#  'close',
#  'up',
#  'his',
#  'business.',
#  'And',
#  'he',
#  'was',
#  'very',
#  'successful',
#  'guy.',
#  'But',
#  "it's",
#  'happening',
#  'more',
#  'and',
#  'more.',
#  'Look',
#  'at',
#  'Obamacare',
#  'with',
#  'a',
#  '$5',
#  'billion',
#  'website.',
#  'I',
#  'have',
#  'many',
#  'websites,',
#  'many,',
#  'many',
#  'websites.',
#  "They're",
#  'all',
#  'over',
#  'the',
#  'place.',
#  'But',
#  'for',
#  '$10,',
#  'okay?',
#  'Now',
#  'everything',
#  'about',
#  'Obamacare',
#  'was',
#  'a',
#  'lie.',
#  'It',
#  'was',
#  'a',
#  'filthy',
#  'lie.',
#  'And',
#  'when',
#  'you',
#  'think',
#  'about',
#  'it,',
#  'lies,',
#  'I',
#  'mean',
#  'are',
#  'they',
#  'prosecuted?',
#  'Does',
#  'anyone',
#  'do',
#  'anything?',
#  'And',
#  'what',
#  'are',
#  'the',
#  'Republican',
#  'politicians',
#  'doing',
#  'about',
#  'it?',
#  'He',
#  'lied',
#  'about',
#  'the',
#  'doctor,',
#  'he',
#  'lied',
#  'about',
#  'every',
#  'aspect.',
#  'You',
#  'can',
#  'keep',
#  'your',
#  'plan.',
#  'And',
#  "you've",
#  'all',
#  'heard',
#  'that',
#  'hundreds',
#  'of',
#  'times.',
#  "That's",
#  'like',
#  'the',
#  'real',
#  'estate',
#  'location,',
#  'location.',
#  'I',
#  "don't",
#  'even',
#  'say',
#  'it',
#  'anymore',
#  'because',
#  'everybody',
#  'goes',
#  'location,',
#  'location.',
#  'But',
#  'you',
#  'have',
#  'heard',
#  'this',
#  'about',
#  'Obamacare.',
#  'And',
#  "it's",
#  'disgraceful.',
#  "It's",
#  'a',
#  'big,',
#  'fat,',
#  'horrible',
#  'lie.',
#  'Your',
#  'deductibles',
#  'are',
#  'going',
#  'through',
#  'the',
#  'roof.',
#  "You're",
#  'not',
#  'going',
#  'to',
#  'get--unless',
#  "you're",
#  'hit',
#  'by',
#  'an',
#  'army',
#  'tank,',
#  "you're",
#  'not',
#  'going',
#  'to',
#  'get',
#  'coverage.',
#  'And',
#  'people',
#  'that',
#  'had',
#  'plans',
#  'that',
#  'they',
#  'loved,',
#  'that',
#  'they',
#  'really',
#  'loved,',
#  "don't",
#  'have',
#  'those',
#  'plans',
#  'anymore.',
#  'So',
#  "it's",
#  'a',
#  'real,',
#  'real',
#  'disaster.',
#  'And',
#  'somebody',
#  'has',
#  'to',
#  'repeal',
#  'and',
#  'replace',
#  'Obamacare.',
#  'And',
#  'they',
#  'have',
#  'to',
#  'do',
#  'it',
#  'fast',
#  'and',
#  'not',
#  'just',
#  'talk',
#  'about',
#  'it.',
#  'Now,',
#  'we',
#  'have',
#  'to',
#  'build',
#  'a',
#  'fence.',
#  'And',
#  "it's",
#  'got',
#  'to',
#  'be',
#  'a',
#  'beauty.',
#  'Who',
#  'can',
#  'build',
#  'better',
#  'than',
#  'Trump?',
#  'I',
#  'build;',
#  "it's",
#  'what',
#  'I',
#  'do.',
#  'I',
#  'build;',
#  'I',
#  'build',
#  'nice',
#  'fences,',
#  'but',
#  'I',
#  'build',
#  'great',
#  'buildings.',
#  'Fences',
#  'are',
#  'easy,',
#  'believe',
#  'me.',
#  'I',
#  'saw',
#  'the',
#  'other',
#  'day',
#  'on',
#  'television',
#  'people',
#  'just',
#  'walking',
#  'across',
#  'the',
#  'border.',
#  "They're",
#  'walking.',
#  'The',
#  'military',
#  'is',
#  'standing',
#  'there',
#  'holding',
#  'guns',
#  'and',
#  'people',
#  'are',
#  'just',
#  'walking',
#  'right',
#  'in',
#  'front,',
#  'coming',
#  'into',
#  'our',
#  'country.',
#  'It',
#  'is',
#  'so',
#  'terrible.',
#  'It',
#  'is',
#  'so',
#  'unfair.',
#  'It',
#  'is',
#  'so',
#  'incompetent.',
#  'And',
#  'we',
#  "don't",
#  'have',
#  'the',
#  'best',
#  'coming',
#  'in.',
#  'We',
#  'have',
#  'people',
#  'that',
#  'are',
#  'criminals,',
#  'we',
#  'have',
#  'people',
#  'that',
#  'are',
#  'crooks.',
#  'You',
#  'can',
#  'certainly',
#  'have',
#  'terrorists.',
#  'You',
#  'can',
#  'certainly',
#  'have',
#  'Islamic',
#  'terrorists.',
#  'You',
#  'can',
#  'have',
#  'anything',
#  'coming',
#  'across',
#  'the',
#  'border.',
#  'We',
#  "don't",
#  'do',
#  'anything',
#  'about',
#  'it.',
#  'So',
#  'I',
#  'would',
#  'say',
#  'that',
#  'if',
#  'I',
#  'run',
#  'and',
#  'if',
#  'I',
#  'win,',
#  'I',
#  'would',
#  'certainly',
#  'start',
#  'by',
#  'building',
#  'a',
#  'very,',
#  'very',
#  'powerful',
#  'border.',
#  'Again,',
#  'the',
#  'politicians',
#  'talk',
#  'about',
#  'it',
#  'and',
#  'they',
#  'do',
#  'nothing',
#  'about',
#  'it.',
#  'Benghazi.',
#  'Oh,',
#  'Benghazi,',
#  'Benghazi.',
#  'Everything',
#  'is',
#  'Benghazi.',
#  'What',
#  'happens?',
#  'Nothing.',
#  'IRS,',
#  'e-mails.',
#  'I',
#  'get',
#  'sued',
#  'all',
#  'the',
#  'time,',
#  'okay.',
#  'I',
#  'run',
#  'a',
#  'big',
#  'business.',
#  'You',
#  'know',
#  "I've",
#  'always',
#  'said',
#  "it's",
#  'very,',
#  'very',
#  'hard',
#  'for',
#  'a',
#  'person',
#  'who',
#  'is',
#  'very',
#  'successful.',
#  'I',
#  'have',
#  'done',
#  'so',
#  'many',
#  'deals.',
#  'Almost',
#  'all',
#  'of',
#  'them',
#  'have',
#  'been',
#  'tremendously',
#  'successful.',
#  "You'll",
#  'see',
#  'that',
#  'when',
#  'I',
#  'file',
#  'my',
#  'statements.',
#  'I',
#  'mean',
#  'you',
#  'will',
#  'see;',
#  'you',
#  'will',
#  'be',
#  'very',
#  'proud',
#  'of',
#  'me,',
#  'okay.',
#  'But',
#  "I've",
#  'always',
#  'said,',
#  'and',
#  'I',
#  'said',
#  'it',
#  'strongly,',
#  "it's",
#  'very',
#  'hard',
#  'for',
#  'somebody',
#  'that',
#  'does',
#  'tremendous',
#  'numbers',
#  'of',
#  'deals',
#  'to',
#  'run',
#  'for',
#  'politics,',
#  'run',
#  'for',
#  'political',
#  'office,',
#  'any',
#  'office,',
#  'let',
#  'alone',
#  'president.',
#  'Because',
#  "you've",
#  'done',
#  'so',
#  'much;',
#  "you've",
#  'beaten',
#  'so',
#  'many',
#  'people;',
#  "you've",
#  'created',
#  'so',
#  'many--',
#  'Look,',
#  'Obama,',
#  'what',
#  'did',
#  'he',
#  'do?',
#  'No',
#  'deal.',
#  'He',
#  'never',
#  'did',
#  'a',
#  'deal.',
#  'He',
#  'did',
#  'one',
#  'deal.',
#  'A',
#  'house.',
#  'And',
#  'if',
#  'you',
#  'did',
#  'that',
#  'house',
#  "you'd",
#  'be',
#  'in',
#  'jail',
#  'right',
#  'now,',
#  'okay.',
#  'He',
#  'got',
#  'away',
#  'with',
#  'murder.',
#  'But',
#  'I',
#  'can',
#  'tell',
#  'you,',
#  'e-mails.',
#  'IRS,',
#  'the',
#  'e-mails,',
#  'thousands',
#  'of',
#  'them,',
#  'they',
#  'were',
#  'lost;',
#  'they',
#  'were',
#  'lost.',
#  'If',
#  'you',
#  'were',
#  'in',
#  'my',
#  'world',
#  'you',
#  'would',
#  'know',
#  'that',
#  'e-mails',
#  "can't",
#  'be',
#  'lost;',
#  'they',
#  "can't",
#  'be',
#  'lost.',
#  'So',
#  'why',
#  "aren't",
#  'our',
#  'politicians',
#  'finding',
#  'out',
#  'where',
#  'those',
#  'e-mails',
#  'are?',
#  'They',
#  'talk',
#  'about',
#  'executive',
#  'orders',
#  'and',
#  'they',
#  'talk',
#  'about',
#  'immigration',
#  'and',
#  'they',
#  'talk',
#  'about',
#  'oh',
#  'well',
#  'we',
#  'have',
#  'to',
#  'stop',
#  'the',
#  'border;',
#  "that's",
#  'the',
#  'end',
#  'of',
#  'it.',
#  'Believe',
#  'me',
#  'if',
#  'I',
#  'did',
#  'something',
#  'you',
#  'would',
#  'have',
#  'a',
#  'border',
#  'that',
#  'would',
#  'be',
#  'great.',
#  'But',
#  'they',
#  'talk',
#  'about',
#  'it.',
#  'And',
#  'then',
#  'you',
#  'have',
#  'a',
#  'president',
#  'that',
#  'does',
#  'an',
#  'executive',
#  'order.',
#  'Nobody',
#  'even',
#  'heard',
#  'of',
#  'an',
#  'executive',
#  'order.',
#  'He',
#  'does',
#  'it',
#  'to',
#  'let',
#  'people',
#  'come',
#  'in',
#  'and',
#  'nobody',
#  'does',
#  'anything',
#  ...]

# %%
#unigram MLE
ngram_gen = ngrams(tokensum, 2)
# print(ngram_gen

#     print(ngram_length)

#     ng = ngrams(tokens, 2)

freqd = nltk.FreqDist(ngram_gen)

for k,v in freqd.items():
#         v = v/ngram_length
    print(k,v)
# Out:
# ('SPEECH', '1\n\n\n...Thank') 1
# ('1\n\n\n...Thank', 'you') 1
# ('you', 'so') 4
# ('so', 'much.') 12
# ('much.', "That's") 1
# ("That's", 'so') 1
# ('so', 'nice.') 3
# ('nice.', "Isn't") 1
# ("Isn't", 'he') 1
# ('he', 'a') 1
# ('a', 'great') 142
# ('great', 'guy.') 6
# ('guy.', 'He') 5
# ('He', "doesn't") 1
# ("doesn't", 'get') 2
# ('get', 'a') 32
# ('a', 'fair') 2
# ('fair', 'press;') 1
# ('press;', 'he') 1
# ('he', "doesn't") 1
# ('get', 'it.') 8
# ('it.', "It's") 2
# ("It's", 'just') 1
# ('just', 'not') 7
# ('not', 'fair.') 1
# ('fair.', 'And') 2
# ('And', 'I') 213
# ('I', 'have') 237
# ('have', 'to') 368
# ('to', 'tell') 57
# ('tell', 'you') 123
# ('you', "I'm") 1
# ("I'm", 'here,') 1
# ('here,', 'and') 2
# ('and', 'very') 5
# ('very', 'strongly') 6
# ('strongly', 'here,') 1
# ('here,', 'because') 1
# ('because', 'I') 70
# ('have', 'great') 27
# ('great', 'respect') 5
# ('respect', 'for') 10
# ('for', 'Steve') 1
# ('Steve', 'King') 1
# ('King', 'and') 1
# ('and', 'have') 9
# ('respect', 'likewise') 1
# ('likewise', 'for') 1
# ('for', 'Citizens') 1
# ('Citizens', 'United,') 1
# ('United,', 'David') 1
# ('David', 'and') 1
# ('and', 'everybody,') 3
# ('everybody,', 'and') 2
# ('and', 'tremendous') 1
# ('tremendous', 'resect') 1
# ('resect', 'for') 1
# ('for', 'the') 133
# ('the', 'Tea') 4
# ('Tea', 'Party.') 3
# ('Party.', 'Also,') 1
# ('Also,', 'also') 1
# ('also', 'the') 1
# ('the', 'people') 103
# ('people', 'of') 21
# ('of', 'Iowa.') 2
# ('Iowa.', 'They') 1
# ('They', 'have') 53
# ('have', 'something') 8
# ('something', 'in') 2
# ('in', 'common.') 1
# ('common.', 'Hard-working') 1
# ('Hard-working', 'people.') 1
# ('people.', 'They') 12
# ('They', 'want') 27
# ('want', 'to') 400
# ('to', 'work,') 2
# ('work,', 'they') 1
# ('they', 'want') 51
# ('to', 'make') 111
# ('make', 'the') 14
# ('the', 'country') 37
# ('country', 'great.') 1
# ('great.', 'I') 12
# ('I', 'love') 107
# ('love', 'the') 30
# ('Iowa.', 'So') 2
# ('So', "that's") 1
# ("that's", 'the') 5
# ('the', 'way') 71
# ('way', 'it') 12
# ('it', 'is.') 25
# ('is.', 'Very') 1
# ('Very', 'simple.') 4
# ('simple.', 'With') 1
# ('With', 'that') 3
# ('that', 'said,') 3
# ('said,', 'our') 1
# ('our', 'country') 85
# ('country', 'is') 21
# ('is', 'really') 11
# ('really', 'headed') 1
# ('headed', 'in') 1
# ('in', 'the') 306
# ('the', 'wrong') 12
# ('wrong', 'direction') 1
# ('direction', 'with') 1
# ('with', 'a') 34
# ('a', 'president') 15
# ('president', 'who') 5
# ('who', 'is') 16
# ('is', 'doing') 13
# ('doing', 'an') 2
# ('an', 'absolutely') 1
# ('absolutely', 'terrible') 1
# ('terrible', 'job.') 1
# ('job.', 'The') 1
# ('The', 'world') 6
# ('world', 'is') 10
# ('is', 'collapsing') 1
# ('collapsing', 'around') 1
# ('around', 'us,') 1
# ('us,', 'and') 4
# ('and', 'many') 9
# ('many', 'of') 37
# ('of', 'the') 467
# ('the', 'problems') 6
# ('problems', "we've") 1
# ("we've", 'caused.') 1
# ('caused.', 'Our') 1
# ('Our', 'president') 3
# ('president', 'is') 1
# ('is', 'either') 2
# ('either', 'grossly') 1
# ('grossly', 'incompetent,') 1
# ('incompetent,', 'a') 1
# ('a', 'word') 3
# ('word', 'that') 2
# ('that', 'more') 1
# ('more', 'and') 10
# ('and', 'more') 8
# ('more', 'people') 5
# ('people', 'are') 63
# ('are', 'using,') 1
# ('using,', 'and') 1
# ('and', 'I') 257
# ('I', 'think') 266
# ('think', 'I') 14
# ('I', 'was') 144
# ('was', 'the') 33
# ('the', 'first') 23
# ('first', 'to') 1
# ('to', 'use') 45
# ('use', 'it,') 2
# ('it,', 'or') 1
# ('or', 'he') 2
# ('he', 'has') 16
# ('has', 'a') 14
# ('a', 'completely') 1
# ('completely', 'different') 1
# ('different', 'agenda') 1
# ('agenda', 'than') 1
# ('than', 'you') 2
# ('you', 'want') 25
# ('to', 'know') 30
# ('know', 'about,') 1
# ('about,', 'which') 1
# ('which', 'could') 2
# ('could', 'be') 29
# ('be', 'possible.') 4
# ('possible.', 'In') 1
# ('In', 'any') 1
# ('any', 'event,') 1
# ('event,', 'Washington') 1
# ('Washington', 'is') 1
# ('is', 'broken,') 1
# ('broken,', 'and') 1
# ('and', 'our') 27
# ('is', 'in') 15
# ('in', 'serious') 4
# ('serious', 'trouble') 2
# ('trouble', 'and') 2
# ('and', 'total') 4
# ('total', 'disarray.') 1
# ('disarray.', 'Very') 1
# ('simple.', 'Politicians') 1
# ('Politicians', 'are') 2
# ('are', 'all') 11
# ('all', 'talk,') 8
# ('talk,', 'no') 8
# ('no', 'action.') 8
# ('action.', 'They') 1
# ('They', 'are') 32
# ('all', 'talk') 2
# ('talk', 'and') 6
# ('and', 'no') 2
# ('action.', 'And') 2
# ('And', "it's") 3
# ("it's", 'constant;') 1
# ('constant;', 'it') 1
# ('it', 'never') 1
# ('never', 'ends.') 1
# ('ends.', 'And') 1
# ('And', "I'm") 2
# ("I'm", 'a') 2
# ('a', 'conservative,') 2
# ('conservative,', 'actually') 1
# ('actually', 'very') 4
# ('very', 'conservative,') 1
# ('conservative,', 'and') 1
# ('and', "I'm") 1
# ('a', 'Republican.') 2
# ('Republican.', 'And') 1
# ("I'm", 'very') 1
# ('very', 'disappointed') 2
# ('disappointed', 'by') 1
# ('by', 'our') 4
# ('our', 'Republican') 1
# ('Republican', 'politicians.') 1
# ('politicians.', 'Because') 1
# ('Because', 'they') 8
# ('they', 'let') 2
# ('let', 'the') 5
# ('the', 'president') 9
# ('president', 'get') 1
# ('get', 'away') 7
# ('away', 'with') 14
# ('with', 'absolute') 1
# ('absolute', 'murder.') 1
# ('murder.', 'You') 1
# ('You', 'see') 11
# ('see', 'always,') 1
# ('always,', 'oh') 1
# ('oh', "we're") 1
# ("we're", 'going') 15
# ('going', 'to') 1509
# ('to', 'do') 283
# ('do', 'this,') 2
# ('this,', "we're") 1
# ('going', 'to--.') 1
# ('to--.', 'Nothing') 1
# ('Nothing', 'ever') 1
# ('ever', 'happens;') 1
# ('happens;', 'nothing') 1
# ('nothing', 'ever') 2
# ('ever', 'happens.') 1
# ('happens.', 'You') 2
# ('You', 'look') 28
# ('look', 'at') 155
# ('at', 'Obamacare.') 1
# ('Obamacare.', 'A') 1
# ('A', 'total') 1
# ('total', 'catastrophe') 1
# ('catastrophe', 'and') 2
# ('and', 'by') 12
# ('by', 'the') 159
# ('it', 'really') 5
# ('really', 'kicks') 2
# ('kicks', 'in') 3
# ('in', 'in') 5
# ('in', "'16") 1
# ("'16", 'and') 1
# ('and', 'it') 54
# ('it', 'is') 39
# ('is', 'going') 91
# ('to', 'be') 463
# ('be', 'a') 90
# ('a', 'disaster.') 25
# ('disaster.', 'People') 1
# ('People', 'are') 9
# ('are', 'closing') 1
# ('closing', 'up') 5
# ('up', 'shops.') 1
# ('shops.', 'Doctors') 1
# ('Doctors', 'are') 2
# ('are', 'quitting') 1
# ('quitting', 'the') 1
# ('the', 'business.') 2
# ('business.', 'I') 2
# ('have', 'a') 262
# ('a', 'friend') 29
# ('friend', 'of') 28
# ('of', 'mine') 13
# ('mine', "who's") 1
# ("who's", 'a') 1
# ('a', 'doctor,') 2
# ('doctor,', 'a') 2
# ('a', 'very') 82
# ('very', 'good') 23
# ('good', 'doctor,') 1
# ('very', 'successful') 11
# ('successful', 'guy.') 2
# ('He', 'said,') 25
# ('said,', 'I') 8
# ('have', 'more') 14
# ('more', 'accountants') 3
# ('accountants', 'than') 3
# ('than', 'I') 5
# ('have', 'patients.') 1
# ('patients.', 'And') 1
# ('And', 'he') 33
# ('he', 'needs') 1
# ('needs', 'because') 1
# ('because', 'it') 13
# ('is', 'so') 34
# ('so', 'complicated') 1
# ('complicated', 'and') 1
# ('and', 'so') 32
# ('so', 'terrible') 1
# ('terrible', 'and') 2
# ('and', "he's") 3
# ("he's", 'never') 1
# ('never', 'had') 5
# ('had', 'that') 6
# ('that', 'before') 1
# ('before', 'and') 1
# ("he's", 'going') 2
# ('to', 'close') 4
# ('close', 'up') 1
# ('up', 'his') 3
# ('his', 'business.') 1
# ('business.', 'And') 2
# ('he', 'was') 63
# ('was', 'very') 19
# ('guy.', 'But') 8
# ('But', "it's") 2
# ("it's", 'happening') 1
# ('happening', 'more') 1
# ('and', 'more.') 1
# ('more.', 'Look') 1
# ('Look', 'at') 20
# ('at', 'Obamacare') 1
# ('Obamacare', 'with') 1
# ('a', '$5') 1
# ('$5', 'billion') 5
# ('billion', 'website.') 1
# ('website.', 'I') 1
# ('have', 'many') 5
# ('many', 'websites,') 1
# ('websites,', 'many,') 1
# ('many,', 'many') 20
# ('many', 'websites.') 1
# ('websites.', "They're") 1
# ("They're", 'all') 1
# ('all', 'over') 60
# ('over', 'the') 79
# ('the', 'place.') 17
# ('place.', 'But') 2
# ('But', 'for') 1
# ('for', '$10,') 2
# ('$10,', 'okay?') 1
# ('okay?', 'Now') 1
# ('Now', 'everything') 1
# ('everything', 'about') 1
# ('about', 'Obamacare') 1
# ('Obamacare', 'was') 1
# ('was', 'a') 90
# ('a', 'lie.') 3
# ('lie.', 'It') 2
# ('It', 'was') 48
# ('a', 'filthy') 1
# ('filthy', 'lie.') 1
# ('lie.', 'And') 4
# ('And', 'when') 16
# ('when', 'you') 57
# ('you', 'think') 32
# ('think', 'about') 13
# ('about', 'it,') 5
# ('it,', 'lies,') 1
# ('lies,', 'I') 1
# ('I', 'mean') 39
# ('mean', 'are') 1
# ('are', 'they') 12
# ('they', 'prosecuted?') 1
# ('prosecuted?', 'Does') 1
# ('Does', 'anyone') 2
# ('anyone', 'do') 1
# ('do', 'anything?') 1
# ('anything?', 'And') 1
# ('And', 'what') 19
# ('what', 'are') 9
# ('are', 'the') 34
# ('the', 'Republican') 19
# ('Republican', 'politicians') 1
# ('politicians', 'doing') 1
# ('doing', 'about') 2
# ('about', 'it?') 3
# ('it?', 'He') 1
# ('He', 'lied') 1
# ('lied', 'about') 2
# ('about', 'the') 54
# ('the', 'doctor,') 1
# ('doctor,', 'he') 1
# ('he', 'lied') 1
# ('about', 'every') 1
# ('every', 'aspect.') 1
# ('aspect.', 'You') 1
# ('You', 'can') 14
# ('can', 'keep') 5
# ('keep', 'your') 4
# ('your', 'plan.') 1
# ('plan.', 'And') 2
# ('And', "you've") 1
# ("you've", 'all') 1
# ('all', 'heard') 1
# ('heard', 'that') 8
# ('that', 'hundreds') 1
# ('hundreds', 'of') 24
# ('of', 'times.') 1
# ('times.', "That's") 1
# ("That's", 'like') 1
# ('like', 'the') 31
# ('the', 'real') 9
# ('real', 'estate') 5
# ('estate', 'location,') 1
# ('location,', 'location.') 2
# ('location.', 'I') 1
# ('I', "don't") 2
# ("don't", 'even') 3
# ('even', 'say') 3
# ('say', 'it') 9
# ('it', 'anymore') 1
# ('anymore', 'because') 2
# ('because', 'everybody') 5
# ('everybody', 'goes') 2
# ('goes', 'location,') 1
# ('location.', 'But') 1
# ('But', 'you') 47
# ('you', 'have') 128
# ('have', 'heard') 3
# ('heard', 'this') 2
# ('this', 'about') 1
# ('about', 'Obamacare.') 1
# ('Obamacare.', 'And') 4
# ("it's", 'disgraceful.') 1
# ('disgraceful.', "It's") 1
# ("It's", 'a') 1
# ('a', 'big,') 7
# ('big,', 'fat,') 1
# ('fat,', 'horrible') 1
# ('horrible', 'lie.') 1
# ('lie.', 'Your') 1
# ('Your', 'deductibles') 2
# ('deductibles', 'are') 4
# ('are', 'going') 104
# ('going', 'through') 6
# ('through', 'the') 14
# ('the', 'roof.') 5
# ('roof.', "You're") 1
# ("You're", 'not') 1
# ('not', 'going') 162
# ('to', 'get--unless') 1
# ('get--unless', "you're") 1
# ("you're", 'hit') 1
# ('hit', 'by') 5
# ('by', 'an') 6
# ('an', 'army') 1
# ('army', 'tank,') 1
# ('tank,', "you're") 1
# ("you're", 'not') 2
# ('to', 'get') 168
# ('get', 'coverage.') 1
# ('coverage.', 'And') 1
# ('And', 'people') 12
# ('people', 'that') 110
# ('that', 'had') 5
# ('had', 'plans') 1
# ('plans', 'that') 2
# ('that', 'they') 33
# ('they', 'loved,') 1
# ('loved,', 'that') 1
# ('they', 'really') 5
# ('really', 'loved,') 1
# ('loved,', "don't") 1
# ("don't", 'have') 2
# ('have', 'those') 5
# ('those', 'plans') 1
# ('plans', 'anymore.') 1
# ('anymore.', 'So') 2
# ('So', "it's") 1
# ("it's", 'a') 3
# ('a', 'real,') 1
# ('real,', 'real') 1
# ('real', 'disaster.') 1
# ('disaster.', 'And') 4
# ('And', 'somebody') 5
# ('somebody', 'has') 2
# ('has', 'to') 20
# ('to', 'repeal') 5
# ('repeal', 'and') 3
# ('and', 'replace') 4
# ('replace', 'Obamacare.') 2
# ('And', 'they') 68
# ('they', 'have') 79
# ('do', 'it') 52
# ('it', 'fast') 1
# ('fast', 'and') 4
# ('and', 'not') 6
# ('not', 'just') 11
# ('just', 'talk') 1
# ('talk', 'about') 74
# ('about', 'it.') 57
# ('it.', 'Now,') 7
# ('Now,', 'we') 5
# ('we', 'have') 293
# ('to', 'build') 47
# ('build', 'a') 39
# ('a', 'fence.') 1
# ('fence.', 'And') 1
# ("it's", 'got') 1
# ('got', 'to') 122
# ('a', 'beauty.') 1
# ('beauty.', 'Who') 1
# ('Who', 'can') 1
# ('can', 'build') 5
# ('build', 'better') 1
# ('better', 'than') 41
# ('than', 'Trump?') 1
# ('Trump?', 'I') 1
# ('I', 'build;') 2
# ('build;', "it's") 1
# ("it's", 'what') 1
# ('what', 'I') 44
# ('I', 'do.') 11
# ('do.', 'I') 15
# ('build;', 'I') 1
# ('I', 'build') 3
# ('build', 'nice') 1
# ('nice', 'fences,') 1
# ('fences,', 'but') 1
# ('but', 'I') 57
# ('build', 'great') 1
# ('great', 'buildings.') 1
# ('buildings.', 'Fences') 1
# ('Fences', 'are') 1
# ('are', 'easy,') 1
# ('easy,', 'believe') 2
# ('believe', 'me.') 16
# ('me.', 'I') 16
# ('I', 'saw') 16
# ('saw', 'the') 13
# ('the', 'other') 74
# ('other', 'day') 20
# ('day', 'on') 3
# ('on', 'television') 15
# ('television', 'people') 1
# ('people', 'just') 1
# ('just', 'walking') 3
# ('walking', 'across') 1
# ('across', 'the') 13
# ('the', 'border.') 12
# ('border.', "They're") 1
# ("They're", 'walking.') 1
# ('walking.', 'The') 1
# ('The', 'military') 2
# ('military', 'is') 8
# ('is', 'standing') 2
# ('standing', 'there') 2
# ('there', 'holding') 1
# ('holding', 'guns') 1
# ('guns', 'and') 6
# ('and', 'people') 10
# ('are', 'just') 3
# ('walking', 'right') 1
# ('right', 'in') 6
# ('in', 'front,') 1
# ('front,', 'coming') 1
# ('coming', 'into') 9
# ('into', 'our') 18
# ('our', 'country.') 41
# ('country.', 'It') 2
# ('It', 'is') 19
# ('so', 'terrible.') 2
# ('terrible.', 'It') 1
# ('so', 'unfair.') 3
# ('unfair.', 'It') 1
# ('so', 'incompetent.') 1
# ('incompetent.', 'And') 1
# ('And', 'we') 83
# ('we', "don't") 5
# ('have', 'the') 85
# ('the', 'best') 46
# ('best', 'coming') 1
# ('coming', 'in.') 14
# ('in.', 'We') 3
# ('We', 'have') 243
# ('have', 'people') 29
# ('that', 'are') 90
# ('are', 'criminals,') 1
# ('criminals,', 'we') 1
# ('are', 'crooks.') 1
# ('crooks.', 'You') 1
# ('can', 'certainly') 3
# ('certainly', 'have') 3
# ('have', 'terrorists.') 1
# ('terrorists.', 'You') 2
# ('have', 'Islamic') 1
# ('Islamic', 'terrorists.') 1
# ('can', 'have') 2
# ('have', 'anything') 3
# ('anything', 'coming') 1
# ('coming', 'across') 3
# ('border.', 'We') 3
# ('We', "don't") 3
# ("don't", 'do') 1
# ('do', 'anything') 3
# ('anything', 'about') 11
# ('it.', 'So') 19
# ('So', 'I') 80
# ('I', 'would') 78
# ('would', 'say') 13
# ('say', 'that') 19
# ('that', 'if') 10
# ('if', 'I') 64
# ('I', 'run') 3
# ('run', 'and') 3
# ('and', 'if') 21
# ('I', 'win,') 6
# ('win,', 'I') 6
# ('would', 'certainly') 2
# ('certainly', 'start') 1
# ('start', 'by') 2
# ('by', 'building') 1
# ('building', 'a') 11
# ('a', 'very,') 9
# ('very,', 'very') 61
# ('very', 'powerful') 1
# ('powerful', 'border.') 1
# ('border.', 'Again,') 1
# ('Again,', 'the') 2
# ('the', 'politicians') 12
# ('politicians', 'talk') 1
# ('about', 'it') 16
# ('it', 'and') 28
# ('and', 'they') 180
# ('they', 'do') 35
# ('do', 'nothing') 1
# ('nothing', 'about') 1
# ('it.', 'Benghazi.') 1
# ('Benghazi.', 'Oh,') 1
# ('Oh,', 'Benghazi,') 1
# ('Benghazi,', 'Benghazi.') 1
# ('Benghazi.', 'Everything') 1
# ('Everything', 'is') 2
# ('is', 'Benghazi.') 1
# ('Benghazi.', 'What') 1
# ('What', 'happens?') 2
# ('happens?', 'Nothing.') 1
# ('Nothing.', 'IRS,') 1
# ('IRS,', 'e-mails.') 1
# ('e-mails.', 'I') 1
# ('I', 'get') 35
# ('get', 'sued') 1
# ('sued', 'all') 1
# ('all', 'the') 65
# ('the', 'time,') 4
# ('time,', 'okay.') 1
# ('okay.', 'I') 1
# ('run', 'a') 2
# ('a', 'big') 65
# ('big', 'business.') 1
# ('business.', 'You') 3
# ('You', 'know') 69
# ('know', "I've") 1
# ("I've", 'always') 3
# ('always', 'said') 2
# ('said', "it's") 2
# ("it's", 'very,') 2
# ('very', 'hard') 17
# ('hard', 'for') 5
# ('for', 'a') 67
# ('a', 'person') 12
# ('person', 'who') 4
# ('is', 'very') 19
# ('very', 'successful.') 4
# ('successful.', 'I') 1
# ('have', 'done') 21
# ('done', 'so') 4
# ('so', 'many') 88
# ('many', 'deals.') 1
# ('deals.', 'Almost') 1
# ('Almost', 'all') 1
# ('all', 'of') 154
# ('of', 'them') 53
# ('them', 'have') 3
# ('have', 'been') 94
# ('been', 'tremendously') 1
# ('tremendously', 'successful.') 1
# ('successful.', "You'll") 1
# ("You'll", 'see') 1
# ('see', 'that') 16
# ('that', 'when') 9
# ('when', 'I') 65
# ('I', 'file') 1
# ('file', 'my') 1
# ('my', 'statements.') 1
# ('statements.', 'I') 1
# ('mean', 'you') 2
# ('you', 'will') 14
# ('will', 'see;') 1
# ('see;', 'you') 1
# ('will', 'be') 92
# ('be', 'very') 27
# ('very', 'proud') 10
# ('proud', 'of') 18
# ('of', 'me,') 3
# ('me,', 'okay.') 1
# ('okay.', 'But') 3
# ('But', "I've") 1
# ('always', 'said,') 1
# ('said,', 'and') 4
# ('I', 'said') 92
# ('said', 'it') 12
# ('it', 'strongly,') 1
# ('strongly,', "it's") 1
# ("it's", 'very') 3
# ('for', 'somebody') 2
# ('somebody', 'that') 13
# ('that', 'does') 5
# ('does', 'tremendous') 1
# ('tremendous', 'numbers') 3
# ('numbers', 'of') 5
# ('of', 'deals') 2
# ('deals', 'to') 1
# ('to', 'run') 24
# ('run', 'for') 20
# ('for', 'politics,') 1
# ('politics,', 'run') 1
# ('for', 'political') 1
# ('political', 'office,') 1
# ('office,', 'any') 1
# ('any', 'office,') 1
# ('office,', 'let') 1
# ('let', 'alone') 1
# ('alone', 'president.') 1
# ('president.', 'Because') 1
# ('Because', "you've") 1
# ("you've", 'done') 1
# ('so', 'much;') 1
# ('much;', "you've") 1
# ("you've", 'beaten') 1
# ('beaten', 'so') 1
# ('many', 'people;') 1
# ('people;', "you've") 1
# ("you've", 'created') 1
# ('created', 'so') 1
# ('so', 'many--') 1
# ('many--', 'Look,') 1
# ('Look,', 'Obama,') 1
# ('Obama,', 'what') 1
# ('what', 'did') 5
# ('did', 'he') 1
# ('he', 'do?') 2
# ('do?', 'No') 1
# ('No', 'deal.') 1
# ('deal.', 'He') 3
# ('He', 'never') 1
# ('never', 'did') 2
# ('did', 'a') 24
# ('a', 'deal.') 13
# ('He', 'did') 5
# ('did', 'one') 1
# ('one', 'deal.') 1
# ('deal.', 'A') 1
# ('A', 'house.') 1
# ('house.', 'And') 1
# ('And', 'if') 27
# ('if', 'you') 85
# ('you', 'did') 1
# ('did', 'that') 6
# ('that', 'house') 1
# ('house', "you'd") 1
# ("you'd", 'be') 2
# ('be', 'in') 16
# ('in', 'jail') 2
# ('jail', 'right') 1
# ('right', 'now,') 7
# ('now,', 'okay.') 1
# ('okay.', 'He') 1
# ('He', 'got') 3
# ('got', 'away') 2
# ('with', 'murder.') 1
# ('murder.', 'But') 1
# ('But', 'I') 113
# ('I', 'can') 54
# ('can', 'tell') 18
# ('tell', 'you,') 26
# ('you,', 'e-mails.') 1
# ('e-mails.', 'IRS,') 1
# ('IRS,', 'the') 1
# ('the', 'e-mails,') 1
# ('e-mails,', 'thousands') 1
# ('thousands', 'of') 57
# ('of', 'them,') 12
# ('them,', 'they') 7
# ('they', 'were') 43
# ('were', 'lost;') 1
# ('lost;', 'they') 2
# ('were', 'lost.') 1
# ('lost.', 'If') 1
# ('If', 'you') 21
# ('you', 'were') 7
# ('were', 'in') 4
# ('in', 'my') 26
# ('my', 'world') 1
# ('world', 'you') 1
# ('you', 'would') 8
# ('would', 'know') 1
# ('know', 'that') 30
# ('that', 'e-mails') 1
# ('e-mails', "can't") 1
# ("can't", 'be') 3
# ('be', 'lost;') 1
# ('they', "can't") 1
# ('be', 'lost.') 2
# ('lost.', 'So') 1
# ('So', 'why') 3
# ('why', "aren't") 2
# ("aren't", 'our') 1
# ('our', 'politicians') 4
# ('politicians', 'finding') 1
# ('finding', 'out') 1
# ('out', 'where') 3
# ('where', 'those') 1
# ('those', 'e-mails') 1
# ('e-mails', 'are?') 1
# ('are?', 'They') 1
# ('They', 'talk') 3
# ('about', 'executive') 3
# ('executive', 'orders') 4
# ('orders', 'and') 1
# ('they', 'talk') 8
# ('about', 'immigration') 2
# ('immigration', 'and') 9
# ('about', 'oh') 1
# ('oh', 'well') 1
# ('well', 'we') 2
# ('to', 'stop') 40
# ('stop', 'the') 7
# ('the', 'border;') 2
# ('border;', "that's") 1
# ('the', 'end') 18
# ('end', 'of') 13
# ('of', 'it.') 51
# ('it.', 'Believe') 5
# ('Believe', 'me') 1
# ('me', 'if') 1
# ('I', 'did') 28
# ('did', 'something') 2
# ('something', 'you') 1
# ('would', 'have') 74
# ('a', 'border') 1
# ('border', 'that') 1
# ('that', 'would') 6
# ('would', 'be') 39
# ('be', 'great.') 3
# ('great.', 'But') 4
# ('But', 'they') 29
# ('it.', 'And') 61
# ('And', 'then') 73
# ('then', 'you') 18
# ('president', 'that') 7
# ('does', 'an') 2
# ('an', 'executive') 6
# ('executive', 'order.') 4
# ('order.', 'Nobody') 1
# ('Nobody', 'even') 4
# ('even', 'heard') 2
# ('heard', 'of') 6
# ('of', 'an') 9
# ('order.', 'He') 1
# ('He', 'does') 1
# ('does', 'it') 9
# ('it', 'to') 33
# ('to', 'let') 23
# ('let', 'people') 7
# ('people', 'come') 4
# ('come', 'in') 27
# ('in', 'and') 22
# ('and', 'nobody') 8
# ('nobody', 'does') 1
# ('does', 'anything') 2
# ('executive', 'orders.') 2
# ('orders.', 'Why') 1
# ('Why', "didn't") 1
# ("didn't", 'they') 1
# ('they', 'go') 21
# ('go', 'to') 59
# ('to', 'court') 1
# ('court', 'and') 2
# ('and', 'ask') 1
# ('ask', 'for') 4
# ('for', 'declaratory') 1
# ('declaratory', 'judgment--which') 1
# ('judgment--which', 'is') 1
# ('is', 'something') 11
# ('something', 'that') 21
# ('you', 'know') 142
# ('know', 'somebody') 1
# ('somebody', 'is') 4
# ('to', 'go') 78
# ('go', 'after') 6
# ('after', 'you') 2
# ('you', 'and') 13
# ('and', 'when') 11
# ('when', "it's") 1
# ("it's", 'in') 1
# ('in', 'writing,') 1
# ('writing,', 'and') 1
# ("he's", 'been') 1
# ('been', 'saying') 10
# ('saying', 'it') 5
# ('it', 'for') 17
# ('a', 'long') 37
# ('long', 'time;') 1
# ('time;', 'he') 1
# ('he', 'said,') 24
# ('said,', "I'm") 1
# ("I'm", 'going') 3
# ('to', 'approve') 4
# ('approve', 'this') 1
# ('this', 'and') 19
# ('and', 'that--why') 1
# ('that--why', "didn't") 1
# ("didn't", 'our') 1
# ('our', 'Republicans') 1
# ('Republicans', 'go') 1
# ('go', 'in') 11
# ('and', 'get') 7
# ('a', 'declaratory') 1
# ('declaratory', 'judgment') 1
# ('judgment', 'from') 1
# ('from', 'the') 56
# ('the', 'courts') 1
# ('courts', 'because') 1
# ('because', 'you') 22
# ('you', 'could') 18
# ('could', 'have') 27
# ('have', 'started') 1
# ('started', 'the') 4
# ('the', 'process') 4
# ('process', 'six') 1
# ('six', 'months') 4
# ('months', 'earlier.') 1
# ('earlier.', 'Instead') 1
# ('Instead', 'they') 1
# ('a', 'weak') 1
# ('weak', 'lawsuit,') 1
# ('lawsuit,', 'that') 1
# ('that', 'probably') 3
# ('probably', 'the') 5
# ('the', 'time') 13
# ('time', "it's") 1
# ("it's", 'finished,') 1
# ('finished,', 'I') 1
# ('I', 'know') 60
# ('know', 'so') 1
# ('so', 'much') 64
# ('much', 'about') 6
# ('about', 'this,') 2
# ('this,', 'six,') 1
# ('six,', 'seven,') 3
# ('seven,', 'eight') 2
# ('eight', 'years') 2
# ('years', 'from') 1
# ('from', 'now') 2
# ('now', "everyone's") 1
# ("everyone's", 'going') 1
# ('to', 'forget') 4
# ('forget', 'about') 3
# ('it.', "We'll") 1
# ("We'll", 'be') 1
# ('be', 'into') 1
# ('into', 'a') 9
# ('a', 'different') 13
# ('different', 'mode,') 1
# ('mode,', 'and') 1
# ('country', 'will') 4
# ('be', 'further') 1
# ('further', 'destroyed.') 1
# ('destroyed.', 'So') 1
# ('So', 'we') 55
# ('do', 'something.') 3
# ('something.', 'Jobs.') 1
# ('Jobs.', 'China.') 1
# ('China.', 'I') 14
# ('mean', "I've") 1
# ("I've", 'made') 1
# ('made', 'so') 1
# ('much', 'money') 11
# ('money', 'fighting') 1
# ('fighting', 'against') 1
# ('against', 'the') 15
# ('the', 'Chinese.') 1
# ('Chinese.', 'One') 1
# ('One', 'of') 20
# ('best', 'deals') 1
# ('deals', 'I') 1
# ('I', 'ever') 3
# ('ever', 'did') 1
# ('did', 'was') 10
# ('was', 'against') 9
# ('the', 'Chinese,') 2
# ('Chinese,', 'and') 1
# ('they', 'respect') 1
# ('respect', 'me') 1
# ('me', 'for') 5
# ('for', 'it.') 17
# ('know', 'them.') 1
# ('them.', 'And') 8
# ('they', 'say,') 13
# ('say,', 'we') 1
# ('we', "can't") 4
# ("can't", 'believe') 3
# ('believe', 'what') 2
# ('what', "we're") 1
# ("we're", 'getting') 1
# ('getting', 'away') 4
# ('away', 'with.') 1
# ('with.', 'We') 4
# ('We', "can't") 5
# ('believe', 'how') 1
# ('how', 'stupid') 4
# ('stupid', 'your') 1
# ('your', 'leaders') 1
# ('leaders', 'are.') 1
# ('are.', 'They') 5
# ('They', 'tell') 1
# ('tell', 'me') 9
# ('me', 'that.') 3
# ('that.', 'Now') 1
# ('Now', 'they') 3
# ('they', "don't") 6
# ("don't", 'know') 7
# ('know', "I'm") 1
# ('go', 'and') 12
# ('and', 'make') 8
# ('make', 'a') 42
# ('a', 'speech') 13
# ('speech', 'about') 1
# ('it,', 'but') 2
# ('but', 'why') 3
# ('why', 'not.') 1
# ('not.', 'But') 4
# ('they', 'tell') 4
# ('that.', 'And') 22
# ('And', 'by') 34
# ('the', 'way,') 79
# ('way,', 'especially') 1
# ('especially', 'for') 4
# ('the', 'folks') 7
# ('folks', 'here') 1
# ('here', 'that') 1
# ('that', 'sell') 1
# ('sell', 'so') 1
# ('so', 'much--goods,') 1
# ('much--goods,', 'I') 1
# ('mean', 'the') 4
# ('the', 'goods') 1
# ('goods', 'you') 1
# ('you', 'sell') 1
# ('sell', 'are') 1
# ('are', 'incredible;') 1
# ('incredible;', 'I') 1
# ('know', 'if') 33
# ('if', "you've") 1
# ("you've", 'been') 2
# ('been', 'watching') 7
# ('watching', "what's") 1
# ("what's", 'happening') 2
# ('happening', 'with') 7
# ('with', 'the') 139
# ('the', 'devaluations') 2
# ('devaluations', 'of') 2
# ('of', 'so') 1
# ('many', 'countries.') 2
# ('countries.', 'The') 1
# ('The', 'Euro,') 1
# ('Euro,', 'China') 1
# ('China', 'is') 13
# ('going', 'crazy') 1
# ('crazy', 'with') 1
# ('the', 'devaluation.') 1
# ('devaluation.', 'I') 1
# ('I', 'never') 18
# ('never', 'thought') 9
# ('thought', 'that') 6
# ('that', "they'd") 1
# ("they'd", 'have') 1
# ('the', 'guts') 1
# ('guts', 'to') 2
# ('do', 'what') 16
# ('what', "they're") 4
# ("they're", 'doing.') 3
# ('doing.', 'They') 4
# ('are', 'devaluing') 1
# ('devaluing', 'down') 1
# ('down', 'to') 8
# ('to', 'nothing.') 2
# ('nothing.', 'And') 6
# ('what', "it's") 1
# ("it's", 'going') 6
# ('do', 'is') 21
# ('is', 'make') 1
# ('make', 'it') 25
# ('it', 'impossible') 7
# ('impossible', 'for') 9
# ('for', 'you') 7
# ('you', 'to') 11
# ('to', 'sell') 6
# ('sell', 'your') 1
# ('your', 'product;') 1
# ('product;', "it's") 1
# ('going', 'make') 1
# ('to', 'compete.') 4
# ('compete.', 'And') 2
# ('And', "they're") 1
# ("they're", 'getting') 1
# ('with', 'it.') 10
# ('they', "wouldn't") 1
# ("wouldn't", 'have') 1
# ('have', 'even') 1
# ('even', 'done') 1
# ('done', 'it') 10
# ('it', 'two') 1
# ('two', 'years') 5
# ('years', 'ago,') 18
# ('ago,', 'but') 1
# ('but', 'now') 3
# ('now', 'they') 5
# ('they', 'feel') 2
# ('feel', "we're") 1
# ("we're", 'so') 1
# ('so', 'weak') 1
# ('weak', 'and') 4
# ('and', 'we') 118
# ('have', 'so') 24
# ('many', 'different') 13
# ('different', 'problems') 1
# ('problems', 'all') 1
# ('the', 'world') 58
# ('world', 'that') 3
# ('they', 'can') 17
# ('can', 'do') 26
# ('do', 'it.') 66
# ('it.', 'But') 30
# ('you', 'watch') 3
# ('watch', 'this') 3
# ('this', 'devaluation') 1
# ('devaluation', 'of') 3
# ('of', 'all') 17
# ('it.', 'I') 70
# ('the', 'Euro,') 1
# ('Euro,', 'China,') 1
# ('China,', 'Mexico;') 1
# ('Mexico;', 'everybody') 1
# ('everybody', 'is') 7
# ('is', 'devaluing.') 1
# ('devaluing.', 'And') 1
# ('you', 'hear') 8
# ('hear', 'the') 5
# ('the', 'dollar') 4
# ('dollar', 'is') 1
# ('is', 'getting') 6
# ('getting', 'stronger,') 1
# ('stronger,', 'it') 1
# ('it', 'sounds') 4
# ('sounds', 'good.') 2
# ('good.', 'You') 2
# ('know', "it's") 1
# ("it's", 'one') 1
# ('one', 'of') 134
# ('of', 'those') 21
# ('those', 'things,') 1
# ('things,', 'sounds') 1
# ('good.', 'Be') 1
# ('Be', 'very') 2
# ('very', 'careful.') 3
# ('careful.', 'Be') 1
# ('careful.', 'Because') 1
# ('Because', "we're") 1
# ("we're", 'just') 1
# ('just', 'going') 5
# ('to', 'lose') 5
# ('lose', 'more') 1
# ('more', 'business') 1
# ('business', 'to') 1
# ('to', 'these') 5
# ('these', 'foreign') 1
# ('foreign', 'countries') 2
# ('countries', 'that') 11
# ('that', 'really') 6
# ('really', 'know') 2
# ('know', 'what') 79
# ('what', 'they') 20
# ('they', 'are') 43
# ('are', 'doing.') 2
# ('have', 'it') 9
# ('it', 'set.') 1
# ('set.', "Don't") 1
# ("Don't", 'forget') 1
# ('forget', 'another') 1
# ('another', 'thing.') 2
# ('thing.', 'China') 1
# ('China', 'became') 1
# ('became', 'the') 1
# ('the', 'number') 10
# ('number', 'one') 19
# ('one', 'economic') 1
# ('economic', 'power') 1
# ('power', 'a') 1
# ('a', 'year') 28
# ('year', 'ago.') 3
# ('ago.', 'That') 1
# ('That', 'was') 23
# ('was', 'unthinkable;') 1
# ('unthinkable;', 'to') 1
# ('to', 'think') 9
# ('think', 'that') 22
# ('that', 'that') 2
# ('that', 'was') 40
# ('was', 'going') 48
# ('to', 'happen.') 50
# ('happen.', 'It') 2
# ('was', 'absolutely') 4
# ('absolutely', 'unthinkable.') 1
# ('unthinkable.', 'So') 1
# ('So', 'it') 8
# ('it', 'happened') 1
# ('happened', 'and') 5
# ('and', "it's") 8
# ('very', 'sad.') 4
# ('sad.', 'Now') 1
# ('Now', 'we') 3
# ('we', 'spent') 5
# ('spent', '$2') 5
# ('$2', 'trillion') 3
# ('trillion', 'in') 11
# ('in', 'Iraq.') 7
# ('Iraq.', 'We') 10
# ('We', 'got') 11
# ('got', 'nothing.') 3
# ('nothing.', 'They') 2
# ('They', "don't") 3
# ('even', 'respect') 1
# ('respect', 'us;') 1
# ('us;', 'they') 1
# ('even', 'care') 2
# ('care', 'about') 11
# ('about', 'us.') 1
# ('us.', 'Until') 1
# ('Until', 'they') 1
# ('they', 'started') 5
# ('started', 'getting') 1
# ('getting', 'their') 1
# ('their', 'ass') 1
# ('ass', 'kicked,') 1
# ('kicked,', 'and') 1
# ('and', 'call,') 1
# ('call,', 'oh') 1
# ('oh', 'please') 1
# ('please', 'come') 1
# ('come', 'back') 10
# ('back', 'and') 26
# ('and', 'help') 1
# ('help', 'us.') 4
# ('us.', 'We') 7
# ('We', 'want') 24
# ('want', 'you') 5
# ('you', 'out;') 1
# ('out;', 'then') 1
# ('then', 'all') 3
# ('the', 'sudden') 1
# ('sudden', 'a') 1
# ('a', 'new') 15
# ('new', 'group') 1
# ('group', 'forms,') 1
# ('forms,', 'ISIS.') 1
# ('ISIS.', 'By') 1
# ('By', 'the') 22
# ('way,', 'you') 3
# ('know', 'how') 30
# ('how', 'they') 3
# ('they', 'formed.') 1
# ('formed.', 'They') 1
# ('They', 'took') 3
# ('took', 'the') 4
# ('the', 'oil.') 14
# ('oil.', 'And') 4
# ('And', 'for') 3
# ('for', 'those') 2
# ('those', 'of') 1
# ('of', 'you') 15
# ('you', 'that') 22
# ('that', 'know') 3
# ('know', 'and') 3
# ('and', 'love') 2
# ('love', 'Donald') 1
# ('Donald', 'Trump--there') 1
# ('Trump--there', 'are') 1
# ('are', 'some') 4
# ('some', 'of') 66
# ('of', 'you--have') 1
# ('you--have', 'I') 1
# ('I', 'been') 1
# ('saying', 'for') 2
# ('for', 'four') 7
# ('four', 'years,') 4
# ('years,', 'keep') 1
# ('keep', 'the') 3
# ('oil.', 'So') 1
# ('So', 'now') 4
# ('now', 'ISIS') 3
# ('ISIS', 'has') 4
# ('has', 'the') 15
# ('And', 'the') 51
# ('the', 'stuff') 3
# ('stuff', 'that') 1
# ('that', 'ISIS') 2
# ('ISIS', "doesn't") 1
# ("doesn't", 'have,') 1
# ('have,', 'Iran') 2
# ('Iran', 'is') 17
# ('to', 'take.') 2
# ('take.', 'So') 1
# ('we', 'get') 25
# ('get', 'nothing.') 6
# ('nothing.', 'We') 11
# ('have', '$2') 1
# ('trillion', 'and') 3
# ('have', 'thousands') 13
# ('of', 'lives') 3
# ('lives', 'lost,') 2
# ('lost,', 'thousands,') 1
# ('thousands,', 'and') 1
# ('we', 'have,') 3
# ('have,', 'what') 1
# ('what', 'do') 11
# ('do', 'we') 11
# ('we', 'have.') 9
# ('have.', 'I') 3
# ('mean', 'I') 2
# ('I', 'walk') 1
# ('walk', 'down') 1
# ('down', 'the') 15
# ('the', 'streets') 2
# ('streets', 'of') 2
# ('of', 'New') 4
# ('New', 'York') 14
# ('York', 'and') 3
# ('I', 'see') 42
# ('see', 'so') 4
# ('many', 'wounded') 1
# ('wounded', 'warriors,') 2
# ('warriors,', 'incredible') 1
# ('incredible', 'people.') 6
# ('people.', 'And') 20
# ('to', 'help') 22
# ('help', 'those') 1
# ('those', 'people,') 3
# ('people,', 'we') 1
# ('help', 'our') 2
# ('our', 'vets,') 3
# ('vets,', 'we') 1
# ('our', 'military,') 4
# ('military,', 'we') 2
# ('build', 'our') 7
# ('our', 'military.') 10
# ('military.', 'But,') 1
# ('But,', 'and') 1
# ('it', 'fast;') 1
# ('fast;', 'we') 1
# ('it', 'fast.') 1
# ('fast.', 'We') 4
# ('have', 'incompetent') 3
# ('incompetent', 'people.') 2
# ('They', 'put') 6
# ('put', 'people') 1
# ('people', 'in') 61
# ('in', 'charge') 6
# ('charge', 'that') 2
# ('that', 'have') 27
# ('have', 'no') 66
# ('no', 'clue') 2
# ('clue', 'what') 2
# ('doing.', 'It') 1
# ('It', 'needs') 1
# ('needs', 'money.') 2
# ('money.', 'We') 10
# ('make', 'our') 35
# ('country', 'rich') 7
# ('rich', 'again') 2
# ('again', 'so') 2
# ('so', 'we') 11
# ('we', 'do') 16
# ('do', 'that,') 7
# ('that,', 'so') 1
# ('we', 'can') 34
# ('can', 'save') 1
# ('save', 'Social') 3
# ('Social', 'Security.') 7
# ('Security.', "'Cause") 1
# ("'Cause", "I'm") 1
# ("I'm", 'not') 5
# ('not', 'a') 47
# ('a', 'cutter;') 1
# ('cutter;', "I'll") 1
# ("I'll", 'probably') 1
# ('probably', 'be') 5
# ('be', 'the') 43
# ('the', 'only') 38
# ('only', 'Republican') 1
# ('Republican', 'that') 1
# ('does', 'not') 16
# ('not', 'want') 2
# ('to', 'cut') 11
# ('cut', 'Social') 1
# ('Security.', "I'm") 1
# ('a', 'cutter') 1
# ('cutter', 'of') 1
# ('of', 'Social') 1
# ('Social', 'Security;') 2
# ('Security;', 'I') 1
# ('I', 'want') 146
# ('rich', 'so') 2
# ('so', 'that') 7
# ('that', 'Social') 1
# ('Social', 'Security') 9
# ('Security', 'can') 1
# ('can', 'be') 24
# ('be', 'afforded,') 1
# ('afforded,', 'and') 1
# ('and', 'Medicare') 1
# ('Medicare', 'and') 4
# ('and', 'Medicaid.') 1
# ('Medicaid.', 'Get') 1
# ('Get', 'rid') 4
# ('rid', 'of') 40
# ('the', 'waste,') 1
# ('waste,', 'get') 1
# ('get', 'rid') 27
# ('the', 'fraud,') 2
# ('fraud,', 'but') 1
# ('but', 'you') 16
# ('you', 'deserve') 1
# ('deserve', 'your') 1
# ('your', 'Social') 7
# ('Security;', "you've") 1
# ('been', 'paying') 5
# ('paying', 'your') 1
# ('your', 'Security.') 1
# ('Security.', 'And') 1
# ('And', 'like,') 1
# ('like,', 'I') 3
# ('I', 'like') 40
# ('like', 'Congressman') 1
# ('Congressman', 'Ryan,') 1
# ('Ryan,', 'I') 1
# ('like', 'a') 42
# ('a', 'lot') 253
# ('lot', 'of') 229
# ('are', 'talking') 2
# ('talking', 'about') 72
# ('about', 'you') 1
# ('know', 'cutting') 1
# ('cutting', 'Social') 1
# ('Social', 'Security,') 4
# ('Security,', 'and') 1
# ('way', 'the') 3
# ('the', 'Democrats') 14
# ('Democrats', 'are') 5
# ('are', 'eating') 1
# ('eating', 'your') 1
# ('your', 'lunch') 1
# ('lunch', 'on') 1
# ('on', 'this') 10
# ('this', 'issue.') 1
# ('issue.', "It's") 1
# ("It's", 'an') 3
# ('an', 'issue') 1
# ('issue', 'that') 1
# ('that', "you're") 1
# ('to', 'win;') 3
# ('win;', "you've") 1
# ("you've", 'got') 1
# ('again', 'and') 10
# ('and', 'strong') 2
# ('strong', 'again') 1
# ('that', 'you') 23
# ('you', 'can') 36
# ('can', 'afford') 2
# ('afford', 'it,') 1
# ('it,', 'and') 13
# ('so', 'you') 13
# ('afford', 'military,') 1
# ('military,', 'and') 2
# ('and', 'all') 42
# ('other', 'things.') 8
# ('things.', 'Now,') 1
# ('a', 'game') 1
# ('game', 'changer') 3
# ('changer', 'now,') 1
# ('now,', 'and') 1
# ('and', 'the') 122
# ('the', 'game') 1
# ('changer', 'is') 1
# ('is', 'nuclear') 1
# ('nuclear', 'weapons.') 2
# ('weapons.', 'We') 1
# ('We', 'really') 1
# ('really', 'do') 5
# ('do', 'have') 6
# ('get', 'strong,') 1
# ('strong,', 'and') 1
# ('get', 'strong') 1
# ('strong', 'fast.') 1
# ("can't", 'let') 2
# ('let', 'Iran') 1
# ('Iran', 'get') 1
# ('a', 'nuclear') 3
# ('nuclear', 'weapon.') 3
# ('weapon.', 'We') 1
# ("can't", 'do') 1
# ('it.', "Can't") 1
# ("Can't", 'do') 1
# ('it.', 'We') 39
# ('We', 'cannot') 5
# ('cannot', 'let') 1
# ('let', 'that') 7
# ('that', 'happen.') 4
# ('happen.', 'You') 2
# ('know', 'in') 6
# ('the', 'old') 10
# ('old', 'days,') 3
# ('days,', 'I') 1
# ('have', 'said') 10
# ('said', '100') 1
# ('100', 'years') 3
# ('ago,', '50') 2
# ('50', 'years') 3
# ('ago,', '30') 1
# ('30', 'years') 3
# ('ago,', 'pull') 1
# ('pull', 'out') 1
# ('out', 'and') 35
# ('and', 'let') 5
# ('let', 'them') 14
# ('them', 'fight') 2
# ('fight', 'each') 1
# ('each', 'other.') 7
# ('other.', 'Here') 1
# ('Here', 'we') 4
# ('we', 'are') 72
# ('are', 'in') 13
# ('in', 'Syria.') 7
# ('Syria.', "We're") 1
# ("We're", 'fighting') 2
# ('fighting', 'people') 1
# ('that', 'want') 8
# ('to', 'overturn') 2
# ('overturn', 'Syria.') 1
# ('Syria.', 'Think') 1
# ('Think', 'of') 22
# ('of', 'this.') 6
# ('this.', "We're") 1
# ('fighting', 'ISIS,') 1
# ('ISIS,', 'but') 1
# ('but', 'ISIS') 1
# ('ISIS', 'wants') 1
# ('wants', 'to') 42
# ('overturn', 'the') 1
# ('the', 'government.') 3
# ('government.', 'Maybe') 1
# ('Maybe', 'you') 1
# ('you', 'let') 1
# ('fight', 'for') 8
# ('a', 'little') 83
# ('little', 'while') 8
# ('while', 'and') 1
# ('and', 'then') 61
# ('you', 'take') 8
# ('take', 'out') 7
# ('out', 'the') 13
# ('the', 'one') 39
# ('one', 'that') 23
# ('that', 'remains,') 1
# ('remains,', 'okay.') 1
# ('But', 'think') 6
# ('think', 'of') 42
# ('of', 'it;') 1
# ('it;', 'think') 1
# ('it.', 'ISIS') 1
# ('ISIS', 'is') 7
# ('is', 'fighting') 1
# ('fighting', 'them') 2
# ('them', 'and') 10
# ('are', 'bombing') 1
# ('bombing', 'the') 3
# ('the', 'hell') 35
# ('hell', 'out') 12
# ('out', 'of') 80
# ('them,', 'but') 3
# ('but', 'we') 29
# ('we', 'want') 27
# ('want', 'Syria') 1
# ('Syria', 'to') 1
# ('to', 'fall.') 1
# ('fall.', 'There') 1
# ('There', 'are') 15
# ('are', 'so') 31
# ('many', 'things;') 1
# ('things;', 'there') 1
# ('there', 'are') 20
# ('many', 'things.') 2
# ('things.', 'But') 10
# ('But', 'the') 37
# ('one', 'game') 1
# ('changer', 'that') 1
# ('that', 'we') 56
# ('be', 'careful') 1
# ('careful', 'with,') 1
# ('with,', 'that') 1
# ('we', 'never') 3
# ('never', 'really') 4
# ('really', 'had') 1
# ('had', 'to') 19
# ('about', 'too') 1
# ('too', 'much') 9
# ('much', 'before,') 1
# ('before,', 'other') 1
# ('other', 'than') 12
# ('than', 'a') 2
# ('a', 'cetain') 1
# ('cetain', 'number') 1
# ('number', 'of') 17
# ('of', 'years') 2
# ('ago,', 'is') 2
# ('is', 'the') 51
# ('the', 'nuclear.') 1
# ('nuclear.', 'Nuclear') 1
# ('Nuclear', 'today,') 1
# ('today,', "it's") 1
# ("it's", 'not') 5
# ('not', 'like') 11
# ('like', 'soldiers') 1
# ('soldiers', 'in') 2
# ('in', 'uniforms') 1
# ('uniforms', 'shooting') 1
# ('shooting', 'rifles.') 1
# ('rifles.', 'You') 1
# ('can', 'take') 10
# ('the', 'East') 1
# ('East', 'Coast') 1
# ('Coast', 'of') 1
# ('of', 'this') 40
# ('this', 'country,') 9
# ('country,', 'you') 2
# ('out', 'large') 1
# ('large', 'sections') 1
# ('sections', 'of') 1
# ('the', 'Midwest,') 1
# ('Midwest,', 'you') 1
# ('out', 'things') 1
# ('things', 'that') 27
# ('that', 'were') 5
# ('were', 'unthinkable.') 1
# ('unthinkable.', 'The') 1
# ('The', 'power.') 1
# ('power.', 'And') 1
# ('in', 'a') 88
# ('a', 'position') 6
# ('position', 'where') 1
# ('where', 'that') 2
# ('that', 'never,') 1
# ('never,', 'ever,') 3
# ('ever,', 'ever,') 1
# ('ever,', 'every') 1
# ('every', 'happens.') 1
# ('happens.', "We've") 1
# ("We've", 'never') 1
# ('had', 'this') 2
# ('this', 'before.') 4
# ('before.', 'We') 3
# ('a', 'situation') 4
# ('situation', 'in') 2
# ('in', 'Afghanistan;') 1
# ('Afghanistan;', "we're") 1
# ("we're", 'spending') 1
# ('spending', 'tremendous') 1
# ('tremendous', 'amounts') 6
# ('amounts', 'of') 5
# ('of', 'money') 33
# ('money', 'there.') 1
# ('there.', "We're") 1
# ("We're", 'trying') 1
# ('trying', 'to') 42
# ('do', 'the') 16
# ('the', 'right') 29
# ('right', 'thing.') 8
# ('thing.', 'We') 3
# ('have', 'leadership,') 1
# ('leadership,', 'again--no') 1
# ('again--no', 'leadership') 1
# ('leadership', 'respects') 1
# ('respects', 'us.') 1
# ('us.', 'You') 6
# ('You', 'know,') 214
# ('know,', 'leadership') 1
# ('leadership', 'of') 1
# ('of', 'other') 8
# ('other', 'places') 4
# ('places', 'never') 1
# ('never', 'respect') 1
# ('respect', 'stupid') 1
# ('stupid', 'people,') 3
# ('people,', 'okay,') 1
# ('okay,', "that's") 1
# ("that's", 'one') 1
# ('one', 'thing') 18
# ('thing', "you're") 1
# ("you're", 'going') 2
# ('to', 'find.') 1
# ('find.', 'The') 1
# ('The', 'same') 1
# ('same', 'thing') 6
# ('thing', 'is') 14
# ('is', 'happening') 4
# ('happening', 'there.') 1
# ('there.', 'And') 8
# ('never', 'knew') 1
# ('knew', 'that') 4
# ('that', 'Afghanistan') 1
# ('Afghanistan', 'until') 1
# ('until', 'a') 2
# ('year', 'ago') 3
# ('ago', 'or') 2
# ('or', 'so,') 1
# ('so,', 'Afghanistan') 1
# ('Afghanistan', 'has') 1
# ('has', 'tremendous') 4
# ('tremendous', 'wealth') 2
# ('wealth', 'in') 3
# ('in', 'minerals,') 1
# ('minerals,', 'different,') 1
# ('different,', 'not') 1
# ('not', 'the') 19
# ('the', 'oil,') 6
# ('oil,', 'but') 1
# ('but', 'minerals.') 1
# ('minerals.', 'And') 1
# ('And', "we're") 4
# ("we're", 'fighting') 2
# ('fighting', 'here,') 1
# ('and', 'on') 8
# ('on', 'the') 111
# ('other', 'side') 5
# ('side', 'of') 4
# ('the', 'mountain') 1
# ('mountain', 'China') 1
# ('is', 'taking') 5
# ('taking', 'out') 1
# ('out', 'all') 1
# ('the', 'minerals.') 1
# ('minerals.', "They're") 1
# ("They're", 'taking') 1
# ('taking', 'it') 3
# ('it', 'out.') 12
# ('out.', 'Trillion') 1
# ('Trillion', 'of') 1
# ('of', 'dollars') 33
# ('dollars', 'and') 2
# ('and', 'millions') 14
# ('millions', 'of') 48
# ('dollars', 'of') 1
# ('of', 'minerals.') 1
# ('minerals.', 'So') 1
# ('So', "we're") 3
# ('fighting', 'here') 1
# ('here', 'and') 18
# ('are', 'taking') 2
# ('it', 'out,') 3
# ('out,', 'looking') 1
# ('looking', 'at') 10
# ('at', 'us') 4
# ('us', 'and') 13
# ('and', 'saying') 2
# ('saying', 'thank') 2
# ('thank', 'you') 20
# ('you', 'very') 44
# ('very', 'much') 18
# ('much', 'sucker.') 1
# ('sucker.', "It's") 1
# ("It's", 'really,') 1
# ('really,', 'really') 8
# ('really', 'crazy.') 1
# ('crazy.', 'So') 3
# ('to', 'rebuild') 15
# ('rebuild', 'quickly') 1
# ('quickly', 'our') 1
# ('our', 'infrastructure') 1
# ('infrastructure', 'of') 2
# ('this', 'country.') 31
# ('country.', 'If') 2
# ('If', 'we') 20
# ('we', "don't--") 1
# ("don't--", 'The') 1
# ('The', 'other') 9
# ('day', 'in') 5
# ('in', 'Ohio') 2
# ('Ohio', 'a') 1
# ('a', 'bridge') 3
# ('bridge', 'collapsed.') 1
# ('collapsed.', 'Bridges') 1
# ('Bridges', 'are') 1
# ('are', 'collapsing') 1
# ('collapsing', 'all') 1
# ('the', 'country.') 25
# ('country.', 'The') 8
# ('The', 'reports') 1
# ('reports', 'on') 1
# ('on', 'bridges') 1
# ('bridges', 'and') 3
# ('the', 'like') 1
# ('like', 'are') 1
# ('are', 'unbelievable,') 1
# ('unbelievable,', "what's") 1
# ('with', 'our') 33
# ('our', 'infrastructure.') 3
# ('infrastructure.', 'I') 1
# ('I', 'go') 23
# ('to', 'Saudi') 1
# ('Saudi', 'Arabia,') 5
# ('Arabia,', 'I') 1
# ('to', 'Dubai;') 1
# ('Dubai;', 'I') 1
# ('I', 'am') 36
# ('am', 'doing') 3
# ('doing', 'big') 1
# ('big', 'jobs') 1
# ('jobs', 'in') 3
# ('in', 'Dubai.') 1
# ('Dubai.', 'I') 1
# ('to', 'various') 1
# ('various', 'different') 1
# ('different', 'places.') 2
# ('places.', 'I') 1
# ('to', 'China.') 3
# ('China.', 'They') 3
# ('are', 'building') 2
# ('bridge', 'on') 1
# ('on', 'every') 4
# ('every', 'corner.') 1
# ('corner.', 'They') 1
# ('have', 'bridges') 6
# ('bridges', 'that') 3
# ('that', 'make') 8
# ('the', 'George') 6
# ('George', 'Washington') 7
# ('Washington', 'Bridge') 4
# ('Bridge', 'like') 1
# ('like', 'small') 2
# ('small', 'time') 1
# ('time', 'stuff.') 1
# ('stuff.', "They're") 1
# ("They're", 'building') 1
# ('building', 'the') 2
# ('the', 'most') 46
# ('most', 'incredible') 6
# ('incredible', 'things') 1
# ('things', 'you') 1
# ('have', 'ever') 4
# ('ever', 'seen.') 12
# ('seen.', 'They') 1
# ('building', 'airports') 1
# ('airports', 'in') 2
# ('in', 'Qatar--which') 1
# ('Qatar--which', 'they') 1
# ('they', 'like') 4
# ('like', 'to') 42
# ('to', 'say') 66
# ('say', '"cutter"') 1
# ('"cutter"', 'but') 1
# ('but', "I've") 1
# ('said', '"qatar"') 1
# ('"qatar"', 'so') 1
# ('so', "I'll") 1
# ("I'll", 'keep') 1
# ('keep', 'it') 11
# ('it', '"qatar"') 1
# ('"qatar"', 'what') 1
# ('what', 'the') 19
# ('the', 'hell.') 1
# ('hell.', 'But') 1
# ('But', "they're") 1
# ("they're", 'building,') 1
# ('building,', "they're") 1
# ("they're", 'building') 1
# ('building', 'an') 1
# ('an', 'airport') 3
# ('airport', 'and') 1
# ('have', 'just') 2
# ('just', 'completed') 1
# ('completed', 'an') 1
# ('airport', 'the') 2
# ('the', 'likes') 3
# ('likes', 'of') 3
# ('of', 'which') 6
# ('which', 'you') 2
# ('have', 'never') 15
# ('never', 'seen,') 2
# ('seen,', 'in') 2
# ('in', 'Dubai') 1
# ('Dubai', 'an') 1
# ('never', 'seen.') 5
# ('seen.', 'And') 3
# ('then', 'I') 19
# ('I', 'come') 7
# ('back', 'to') 27
# ('to', 'LaGuardia') 1
# ('LaGuardia', 'where') 1
# ('where', 'the') 10
# ('the', 'runways') 1
# ('runways', 'have') 1
# ('have', 'potholes.') 1
# ('potholes.', 'The') 1
# ('The', 'place') 1
# ('place', 'is') 1
# ('is', 'falling') 2
# ('falling', 'apart.') 3
# ('apart.', 'You') 1
# ('You', 'go') 9
# ('go', 'into') 16
# ('into', 'the') 39
# ('the', 'main') 3
# ('main', 'terminal') 1
# ('terminal', 'and') 1
# ('a', 'terraza') 1
# ('terraza', 'floor') 2
# ('floor', "that's") 1
# ("that's", 'so') 1
# ('so', 'old') 1
# ('old', "it's") 1
# ("it's", 'falling') 1
# ('apart.', 'And') 2
# ('a', 'hole') 1
# ('hole', 'in') 1
# ('in', 'it,') 1
# ('they', 'replace') 1
# ('replace', 'it') 3
# ('it', 'with') 12
# ('with', 'asphalt.') 1
# ('asphalt.', 'So') 1
# ('So', 'you') 16
# ('a', 'white') 1
# ('white', 'terraza') 1
# ('floor', 'and') 2
# ('they', 'put') 6
# ('put', 'asphalt') 1
# ('asphalt', 'all') 1
# ('place.', 'This') 1
# ('This', 'is') 49
# ('is', 'inside,') 1
# ('inside,', 'not') 1
# ('not', 'outside.') 1
# ('outside.', 'And') 1
# ('I', 'just') 67
# ('just', 'left') 2
# ('left', 'Dubai') 1
# ('Dubai', 'where') 1
# ('where', 'they') 23
# ('incredible', 'thing') 1
# ('thing', "you've") 1
# ("you've", 'ever') 1
# ('seen.', 'In') 1
# ('In', 'fact') 2
# ('fact', 'my') 1
# ('my', 'pilot') 1
# ('pilot', 'said') 1
# ('said', 'oh') 1
# ('oh', 'Mr.') 1
# ('Mr.', 'Trump') 5
# ('Trump', 'this') 1
# ('this', 'is') 52
# ('is', 'such') 2
# ('such', 'an') 7
# ('an', 'honor.') 3
# ('honor.', 'I') 3
# ('not', 'an') 4
# ('an', 'honor;') 1
# ('honor;', "they're") 1
# ("they're", 'just') 1
# ('just', 'smart.') 1
# ('smart.', 'But') 1
# ('you', 'look') 56
# ('at', 'LAX,') 1
# ('LAX,', 'and') 1
# ('and', 'you') 95
# ('at', 'Kennedy') 1
# ('Kennedy', 'Airport,') 1
# ('Airport,', 'and') 1
# ('at', 'our') 8
# ('our', 'airports') 1
# ('airports', 'generally,') 1
# ('generally,', 'you') 1
# ('our', 'roadways') 1
# ('roadways', 'where') 1
# ('where', "they're") 1
# ("they're", 'crumbling.') 1
# ('crumbling.', 'You') 1
# ('at', 'all') 13
# ('the', 'things') 26
# ('are', 'bad--') 1
# ('bad--', "I'll") 1
# ("I'll", 'give') 1
# ('give', 'you') 14
# ('you', 'an') 1
# ('an', 'example.') 3
# ('example.', 'And') 2
# ('And', 'this') 13
# ('this', "isn't") 1
# ("isn't", 'part') 1
# ('part', 'of') 10
# ('of', 'what') 12
# ('to', 'say,') 19
# ('say,', 'but') 1
# ('I', 'ride') 1
# ('ride', 'down') 1
# ('the', 'highways') 1
# ('highways', 'and') 1
# ('and', 'somebody') 3
# ('somebody', 'makes') 1
# ('makes', 'those') 1
# ('those', 'guard') 1
# ('guard', 'rails.') 2
# ('rails.', 'You') 1
# ('know', 'the') 35
# ('the', 'guard') 1
# ('rails.', 'The') 1
# ('The', 'ones') 1
# ('ones', 'that') 5
# ('that', 'sort') 1
# ('sort', 'of') 34
# ('of', 'go') 1
# ('go', 'like') 1
# ('like', 'this') 12
# ('this', '[demonstrates') 1
# ('[demonstrates', 'with') 1
# ('with', 'hand]') 1
# ('hand]', 'that') 1
# ('are', 'always') 2
# ('always', 'bent,') 1
# ('bent,', 'rusted') 1
# ('rusted', 'and') 1
# ('and', 'horrible.') 1
# ('horrible.', 'Did') 1
# ('Did', 'you') 13
# ('you', 'ever') 15
# ('ever', 'see') 9
# ('see', 'more') 1
# ('more', 'than') 38
# ('than', 'like') 1
# ('like', '20') 1
# ('20', 'feet') 1
# ('feet', 'which') 1
# ('which', "isn't") 1
# ("isn't", 'corroded,') 1
# ('corroded,', 'or') 1
# ('or', 'bent') 1
# ('bent', 'or') 1
# ('or', 'the') 20
# ('the', 'heat,') 1
# ('heat,', 'if') 1
# ('if', 'it') 7
# ('it', 'gets') 1
# ('gets', 'too') 1
# ('too', 'hot,') 1
# ('hot,', 'it') 1
# ('it', 'just') 6
# ('just', 'crushes.') 1
# ('crushes.', 'Now') 1
# ('Now', "they've") 1
# ("they've", 'been') 1
# ('been', 'selling') 1
# ('selling', 'this') 2
# ('this', 'thing') 3
# ('thing', 'for') 7
# ('for', '25') 1
# ('25', 'years.') 1
# ('years.', 'Why') 1
# ('Why', "doesn't") 1
# ("doesn't", 'someone') 1
# ('someone', 'stop') 1
# ('stop', 'them') 1
# ('get', 'something') 1
# ('that', 'works.') 1
# ('works.', 'Because') 1
# ("don't", 'know;') 1
# ('know;', 'they') 1
# ('know', "what's") 1
# ("what's", 'happening.') 1
# ('happening.', 'Somebody') 1
# ('Somebody', 'made') 1
# ('made', 'a') 21
# ('money', 'on') 5
# ('on', 'that.') 3
# ('that.', 'They') 8
# ('what', 'is') 14
# ('is', 'happening.') 2
# ('happening.', 'So') 1
# ('country', 'great') 7
# ('great', 'again.') 34
# ('again.', 'We') 18
# ('rebuild', 'our') 14
# ('country.', 'And') 14
# ('long', 'way') 3
# ('way', 'to') 7
# ('to', 'go.') 5
# ('go.', 'We') 2
# ('We', 'are') 42
# ('just', 'in') 4
# ('in', 'such') 2
# ('such', 'serious') 1
# ('trouble', 'because') 1
# ('because', 'we') 36
# ('we', 'owe') 9
# ('owe', 'so') 1
# ('much', 'money.') 5
# ('money.', 'Now') 2
# ('owe', 'it') 3
# ('to', 'the') 111
# ('Chinese,', 'a') 1
# ('We', 'owe') 16
# ('to', 'other') 9
# ('other', 'countries.') 4
# ('countries.', "They're") 2
# ("They're", 'the') 1
# ('the', 'ones') 4
# ('that', 'hold') 1
# ('hold', 'the') 1
# ('the', 'debt.') 1
# ('debt.', 'And') 2
# ('then', 'we') 21
# ('we', 'give') 10
# ('give', 'them') 13
# ('them', 'money.') 2
# ('have', 'countries') 1
# ('owe', 'money') 1
# ('money', 'to') 14
# ('to', 'and') 2
# ('and', 'yet') 9
# ('yet', "we're") 1
# ("we're", 'giving') 1
# ('giving', 'them') 4
# ('them', 'subsidies.') 2
# ('subsidies.', 'I') 1
# ('just', 'ordered') 2
# ('ordered', 'thousands') 2
# ('of', 'television') 2
# ('television', 'sets') 2
# ('sets', 'and') 1
# ('and', 'between') 1
# ('between', 'LG') 1
# ('LG', 'and') 1
# ('and', 'Samsung') 1
# ('Samsung', 'and') 1
# ('you', 'know--') 1
# ('know--', 'No') 1
# ('No', 'American') 1
# ('American', 'company') 1
# ('company', 'comes') 1
# ('comes', 'to') 10
# ('to', 'see') 44
# ('see', 'and') 1
# ('and', 'comes') 1
# ('to', 'bid.') 1
# ('bid.', "It's") 1
# ("It's", 'South') 1
# ('South', 'Korea,') 6
# ('Korea,', 'and') 1
# ('and', 'whenever') 1
# ('whenever', 'they') 1
# ('a', 'problem') 11
# ('problem', 'we') 5
# ('we', 'send') 6
# ('send', 'the') 2
# ('the', 'battleships,') 1
# ('battleships,', 'we') 1
# ('the', 'destroyers,') 1
# ('destroyers,', 'we') 1
# ('send', 'our') 2
# ('our', 'airplanes,') 1
# ('airplanes,', "we're") 1
# ('to', 'protect') 26
# ('protect', 'them.') 5
# ('them.', 'What') 3
# ('What', 'are') 5
# ('are', 'we') 13
# ('we', 'doing;') 1
# ('doing;', 'why') 1
# ("aren't", 'they') 3
# ('they', 'paying') 2
# ('paying', 'us?') 1
# ('us?', 'Why') 1
# ('Why', "aren't") 2
# ('paying', 'us;') 1
# ('us;', 'what') 1
# ('we', 'doing?') 2
# ('doing?', 'I') 1
# ('I', 'order') 7
# ('order', 'thousands') 3
# ('thousands', 'and') 11
# ('and', 'thousands') 13
# ('of', 'sets') 1
# ('sets', 'all') 1
# ('time,', 'for') 1
# ('for', 'some') 10
# ('some', 'reason') 4
# ('reason', "it's") 1
# ("it's", 'South') 1
# ('South', 'Korea.') 12
# ('Korea.', 'You') 2
# ('know', 'whether') 6
# ('whether', "it's") 2
# ("it's", 'China,') 1
# ('China,', 'South') 1
# ('Korea,', 'but') 1
# ('but', 'in') 5
# ('in', 'this') 64
# ('this', 'case') 2
# ('case', 'televisions,') 1
# ('televisions,', 'South') 1
# ('Korea.', 'Why') 1
# ('they', 'doing') 2
# ('doing', 'something') 4
# ('something', 'to') 4
# ('to', 'justify') 2
# ('justify', 'what') 1
# ('going', 'on?') 2
# ('on?', 'Now,') 1
# ('very', 'important') 12
# ('important', 'election') 1
# ('election', 'coming') 2
# ('coming', 'up.') 3
# ('up.', 'We') 2
# ('a', 'presidential') 3
# ('presidential', 'election') 1
# ('up.', 'And') 10
# ('have', 'some') 25
# ('some', 'good') 3
# ('good', 'people.') 10
# ('people.', 'Nobody') 1
# ('Nobody', 'like') 1
# ('like', 'Trump') 1
# ('Trump', 'of') 1
# ('of', 'course,') 5
# ('course,', 'but') 1
# ('but', 'these') 3
# ('these', 'are') 20
# ('are', 'minor') 3
# ('minor', 'details.') 1
# ('details.', 'We') 1
# ('people.', "It'") 1
# ("It'", "can't") 1
# ('be', 'Mitt') 1
# ('Mitt', 'because') 1
# ('because', 'Mitt') 1
# ('Mitt', 'ran') 1
# ('ran', 'and') 1
# ('and', 'failed.') 1
# ('failed.', 'He') 1
# ('He', 'failed.') 1
# ('failed.', 'I') 1
# ('I', 'liked') 1
# ('liked', 'him.') 1
# ('him.', 'Look--like') 1
# ('Look--like', 'him,') 1
# ('him,', 'dislike') 1
# ('dislike', 'him--the') 1
# ('him--the', '47%') 1
# ('47%', 'statement') 1
# ('statement', 'that') 4
# ('that', 'he') 18
# ('he', 'made,') 1
# ('made,', "that's") 1
# ("that's", 'not') 2
# ('going', 'away.') 2
# ('away.', 'The') 1
# ('The', 'Romneycare') 1
# ('Romneycare', 'from') 1
# ('from', 'Massachusetts,') 1
# ('Massachusetts,', "that's") 1
# ('away.', 'What') 1
# ('What', 'do') 11
# ('do', 'you') 38
# ('think', "they're") 1
# ("they're", 'going') 4
# ('say', 'oh') 4
# ('oh', 'we') 1
# ('we', "won't") 1
# ("won't", 'bring') 1
# ('bring', 'that') 5
# ('that', 'up') 4
# ('up', 'this') 3
# ('this', 'time.') 1
# ('time.', "It's") 1
# ("It's", 'not') 4
# ('not', 'fair') 4
# ('fair', 'because') 1
# ('it', 'was') 116
# ('long', 't--') 1
# ('t--', 'That') 1
# ('That', "doesn't") 1
# ("doesn't", 'work.') 1
# ('work.', 'But') 4
# ('But', 'more') 5
# ('more', 'importantly,') 4
# ('importantly,', 'he') 1
# ('he', 'choked.') 1
# ('choked.', 'Something') 1
# ('Something', 'happened') 1
# ('happened', 'to') 13
# ('to', 'him') 6
# ('him', 'in') 8
# ('the', 'last') 34
# ('last', 'month.') 2
# ('month.', 'He') 1
# ('He', 'had') 3
# ('that', 'election') 1
# ('election', 'won.') 1
# ('won.', 'And') 4
# ('And', 'let') 3
# ('let', 'me') 22
# ('me', 'tell') 19
# ('you', 'something.') 7
# ('something.', 'That') 1
# ('That', 'election,') 1
# ('election,', 'sort') 1
# ('of', 'like') 6
# ('a', 'dealmaker') 3
# ('dealmaker', 'that') 1
# ('that', "can't") 2
# ("can't", 'close') 2
# ('close', 'the') 4
# ('the', 'deal.') 6
# ('deal.', 'I') 9
# ('know', 'many') 2
# ('those', 'guys;') 1
# ...
# ('while.', 'They') 1
# ('money.', 'Carried') 1
# ('Carried', 'interest.') 1
# ('interest.', 'So') 1
# ('it', 'ends') 1
# ('carried', 'interest') 1
# ('interest', 'through') 1
# ('through', 'speculative') 1
# ('speculative', 'partnerships') 1
# ('partnerships', 'that') 1
# ('not', 'grow') 1
# ('grow', 'businesses') 1
# ('businesses', 'or') 1
# ('or', 'create') 1
# ('not', 'risking') 1
# ('risking', 'their') 1
# ('own', 'capital.') 1
# ('capital.', 'Changes') 1
# ('for', 'business') 1
# ('business', '–') 1
# ('now,', 'so') 1
# ('important,', 'because') 1
# ('about', 'business.') 1
# ('business.', 'It’s') 1
# ('about', 'jobs.') 1
# ('have', '93') 1
# ('93', 'million') 1
# ('serious', 'trouble,') 1
# ('trouble,', 'that') 1
# ('to', 'work;') 1
# ('work;', 'they') 1
# ('can’t', 'work.') 1
# ('for', 'business,') 1
# ('business,', 'no') 1
# ('business', 'of') 1
# ('any', 'size') 1
# ('size', 'from') 1
# ('a', 'Fortune') 1
# ('Fortune', '500') 1
# ('500', 'company') 1
# ('a', 'mom') 1
# ('mom', 'and') 1
# ('and', 'pop') 1
# ('pop', 'shop') 1
# ('shop', 'to') 1
# ('a', 'freelancer') 1
# ('freelancer', 'living') 1
# ('living', 'from') 1
# ('from', 'gig') 1
# ('gig', 'to') 1
# ('to', 'gig') 1
# ('gig', 'will') 1
# ('pay', 'more') 1
# ('than', '15%') 1
# ('15%', 'of') 1
# ('business', 'income') 1
# ('income', 'in') 1
# ('taxes.', 'Big') 1
# ('Big', 'reduction.') 1
# ('reduction.', 'A') 2
# ('A', 'one-time') 1
# ('one-time', 'deemed') 1
# ('deemed', 'repatriation') 1
# ('repatriation', 'of') 1
# ('of', 'corporate') 1
# ('corporate', 'cash') 1
# ('cash', 'held') 1
# ('held', 'overseas') 1
# ('overseas', 'at') 1
# ('at', 'significantly') 1
# ('significantly', 'discount') 2
# ('discount', 'which') 1
# ('which', 'coming') 1
# ('back', 'at') 1
# ('a', 'significantly') 1
# ('discount', '–') 1
# ('–', '10%.') 1
# ('10%.', 'So') 1
# ('back', 'discounted') 1
# ('discounted', 'at') 1
# ('a', '10%') 1
# ('10%', 'tax') 1
# ('tax', 'rate') 3
# ('rate', 'and') 1
# ('and', 'ends') 1
# ('the', 'deferral') 1
# ('deferral', 'of') 1
# ('of', 'taxes') 1
# ('on', 'corporate') 1
# ('corporate', 'income') 1
# ('income', 'earned') 1
# ('earned', 'abroad.') 1
# ('abroad.', 'Now,') 1
# ('called', 'corporate') 1
# ('inversion.', 'It’s') 1
# ('huge', 'subject.') 1
# ('subject.', 'I’ve') 1
# ('watching', 'politicians') 1
# ('politicians', 'now') 1
# ('years', 'talking') 1
# ('about', 'bringing') 1
# ('bringing', 'this') 1
# ('probably', '$2.5') 1
# ('trillion.', 'Everybody') 1
# ('–', 'Republicans,') 1
# ('Republicans,', 'Democrats,') 1
# ('Democrats,', 'everybody.') 1
# ('everybody.', 'They') 1
# ('go', 'about') 1
# ('reason', 'companies') 1
# ('companies', 'aren’t') 1
# ('aren’t', 'bringing') 1
# ('back', 'is') 1
# ('is', 'onerous.') 1
# ('onerous.', 'It') 1
# ('fact,', 'many') 1
# ('States.', 'They’re') 1
# ('our', 'shores') 1
# ('shores', 'to') 1
# ('and', 'collect') 1
# ('collect', 'their') 1
# ('going', 'actually') 1
# ('actually', 'moving') 1
# ('moving', 'out') 1
# ('States', 'for') 1
# ('too', 'high') 1
# ('can’t', 'bring') 2
# ('country', 'when') 1
# ('when', 'everybody') 1
# ('wants', 'them') 1
# ('called', 'leadership.') 1
# ('money', 'brought') 1
# ('in.', 'As') 1
# ('overseas.', 'I') 1
# ('We', 'filed') 1
# ('papers.', 'We’ve') 1
# ('a', 'half.') 1
# ('half.', 'We') 1
# ('money', 'stays') 1
# ('stays', 'in') 1
# ('happens.', 'Not') 1
# ('Not', 'good') 1
# ('of', 'leadership') 1
# ('leadership', 'that') 1
# ('this', 'done') 1
# ('important.', 'But') 1
# ('watching', 'it') 1
# ('agrees', 'to.') 1
# ('to.', 'We') 1
# ('also', 'reduce') 1
# ('reduce', 'or') 1
# ('or', 'eliminate') 1
# ('eliminate', 'some') 1
# ('some', 'business') 1
# ('business', 'loopholes') 1
# ('loopholes', '–') 1
# ('actually', '–') 1
# ('and', 'deductions') 1
# ('deductions', 'made') 1
# ('made', 'unnecessary') 1
# ('unnecessary', 'or') 1
# ('or', 'redundant') 1
# ('redundant', 'by') 1
# ('new', 'lower') 1
# ('lower', 'tax') 1
# ('rate', 'on') 1
# ('on', 'business') 1
# ('business', 'income.') 1
# ('income.', 'The') 1
# ('rate', 'now') 1
# ('these', 'deductions') 2
# ('deductions', 'which') 3
# ('are', 'complicated,') 1
# ('complicated,', 'which') 1
# ('which', 'don’t') 1
# ('make', 'sense,') 1
# ('are', 'unfair') 1
# ('unfair', 'are') 1
# ('are', 'gone.') 1
# ('we', 'phase') 1
# ('phase', 'in') 1
# ('reasonable', 'cap') 1
# ('cap', 'on') 1
# ('the', 'deductability') 1
# ('deductability', 'of') 1
# ('business', 'interest') 1
# ('interest', 'expense.') 1
# ('expense.', 'So') 1
# ('of', 'papers') 1
# ('actually', 'if') 1
# ('know', 'business') 1
# ('business', 'is') 1
# ('so', 'complex.') 1
# ('complex.', 'And') 1
# ('to', 'hand') 1
# ('hand', 'them') 1
# ('out', 'right') 1
# ('see', 'we') 1
# ('amazing', 'code.') 1
# ('be', 'simple.') 1
# ('simple.', 'It') 1
# ('easy.', 'It') 1
# ('fair.', 'It’s') 1
# ('It’s', 'graduated.') 1
# ('graduated.', 'As') 1
# ('in', 'income,') 1
# ('income,', 'you') 1
# ('little', 'more.') 1
# ('more.', 'Some') 1
# ('unfair', 'deductions') 1
# ('deductions', 'that') 1
# ('that', 'certain') 1
# ('given', 'who') 1
# ('who', 'make') 1
# ('be', 'available') 1
# ('available', 'any') 1
# ('longer.', 'But') 1
# ('actually', 'believe') 1
# ('believe', 'they’ll') 1
# ('better', 'because') 1
# ('economy', 'will') 2
# ('will', 'grow.') 1
# ('grow.', 'It') 1
# ('grow', 'rapidly.') 1
# ('rapidly.', 'And') 1
# ('something', 'very') 1
# ('special.', 'Now,') 1
# ('being', 'said') 1
# ('and', 'before') 1
# ('questions,', 'we') 1
# ('money', 'we’re') 1
# ('we’re', 'spending.') 1
# ('spending.', 'I') 1
# ('read', 'where') 1
# ('where', 'a') 1
# ('a', 'washer') 2
# ('washer', '–') 2
# ('washer', 'is?') 1
# ('is?', 'Nuts,') 1
# ('Nuts,', 'bolts,') 1
# ('bolts,', 'and') 1
# ('and', 'washer') 1
# ('send', 'from') 1
# ('one', 'state') 1
# ('state', 'to') 1
# ('to', 'another,') 1
# ('another,', 'it') 1
# ('a', '19') 1
# ('19', 'set') 1
# ('set', 'washer') 1
# ('washer', 'and') 1
# ('it', 'cost') 1
# ('cost', '$900,000') 1
# ('$900,000', 'and') 1
# ('some', 'odd') 1
# ('odd', 'dollars') 1
# ('to', 'there.') 1
# ('many', 'examples.') 1
# ('examples.', 'Hammers') 1
# ('Hammers', 'that') 1
# ('that', 'cost') 1
# ('cost', '$800') 1
# ('$800', 'that') 1
# ('buy', 'in') 1
# ('the', 'store') 1
# ('store', 'for') 1
# ('a', 'tiny') 1
# ('tiny', 'amount') 1
# ('run', 'this') 1
# ('country', 'properly.') 1
# ('properly.', 'There') 1
# ('saved.', 'We’re') 1
# ('We’re', 'reducing') 1
# ('reducing', 'taxes') 1
# ('but', 'at') 1
# ('same', 'time') 1
# ('time', 'if') 1
# ('President,', 'we') 1
# ('cut', 'so') 1
# ('better', 'country.') 1
# ('losing', 'anything') 2
# ('than', 'we’ll') 1
# ('be', 'balancing') 1
# ('balancing', 'budgets') 1
# ('budgets', 'and') 1
# ('getting', 'them') 1
# ('be.', 'So,') 1
# ('So,', 'this') 1
# ('plan', 'that’s') 1
# ('that’s', 'simple,') 1
# ('simple,', 'that’s') 1
# ('major', 'reduction.') 1
# ('reduction.', 'I') 1
# ('happy.', 'We’ve') 1
# ('We’ve', 'already') 1
# ('already', 'had') 1
# ('good', 'reviews.') 1
# ('reviews.', 'I') 1
# ('plan', 'with') 1
# ('the', 'leading') 1
# ('leading', 'scholars') 1
# ('scholars', 'and') 1
# ('and', 'economists') 1
# ('economists', 'and') 1
# ('and', 'tax') 1
# ('tax', 'experts') 1
# ('experts', 'that') 1
# ('love', 'it;') 1
# ('it;', 'they') 1
# ('say', '"Why') 1
# ('"Why', 'hasn’t') 1
# ('hasn’t', 'this') 1
# ('this', 'been') 1
# ('before?"', 'And') 1
# ('my', 'wheelhouse.') 1
# ('wheelhouse.', 'That’s') 1
# ('well.', 'Whenever') 1
# ('do', 'polls,') 1
# ('polls,', 'I') 1
# ('always', 'come') 1
# ('out', 'way') 1
# ('way', 'above') 1
# ('above', 'everybody') 1
# ('everybody', 'else') 1
# ('else', 'on') 1
# ('on', 'leadership,') 1
# ('leadership,', 'by') 1
# ('way,', 'but') 1
# ('that.', 'So,') 2
# ('has', '–') 1
# ('–', '[applause]') 1
# ('[applause]', '–') 1
# ('you.', 'That’s') 1
# ('That’s', 'amazing.') 1
# ('amazing.', 'That’s') 1
# ('That’s', 'some') 1
# ('actually', 'clapping.') 1
# ('clapping.', 'I’ve') 1
# ('seen', 'that') 1
# ('that', 'before.') 1
# ('before.', 'All') 1
# ('right.', 'Why') 1
# ('Why', 'don’t') 1
# ('questions', 'from') 1
# ('the', 'press?') 1
# ('press?', 'No,') 1
# ('that', 'yet') 1
# ('their', 'approval.') 1
# ('approval.', 'But') 1
# ('country', 'worked') 1
# ('on', 'this.') 1
# ('this.', 'Well,') 1
# ('a', '3%') 1
# ('3%', 'but') 1
# ('be', '5%,') 1
# ('5%,', 'it') 1
# ('be', '6%.') 1
# ('6%.', 'We’re') 1
# ('have', 'growth') 1
# ('growth', 'that') 1
# ('be', 'tremendous.') 1
# ('tremendous.', 'And') 1
# ('than', '3%,') 1
# ('3%,', 'these') 1
# ('really', 'spectacular.') 1
# ('spectacular.', 'And') 1
# ('take', 'into') 1
# ('into', 'account') 1
# ('account', 'in') 1
# ('any', 'big') 1
# ('league', 'fashion') 1
# ('fashion', 'is') 1
# ('the', 'cutting.') 1
# ('cutting.', 'There') 1
# ('much', 'waste') 1
# ('waste', 'in') 1
# ('believe', 'when') 1
# ('there', 'I’ll') 1
# ('cut', 'without') 1
# ('without', 'losing') 1
# ('cut', 'tremendous') 1
# ('amounts', 'off') 1
# ('off', 'of') 1
# ('even', 'showing') 1
# ('showing', 'anything') 1
# ('conservative', 'numbers.') 1
# ('numbers.', 'My') 1
# ('My', 'taxes') 1
# ('taxes', 'will') 1
# ('will', '–') 1
# ('all,', 'I’ll') 1
# ('much', 'simpler') 1
# ('simpler', 'tax') 1
# ('tax', 'statement.') 1
# ('statement.', 'It') 1
# ('much', 'simpler.') 1
# ('simpler.', 'When') 1
# ('do', 'my') 1
# ('my', 'return,') 1
# ('return,', 'it') 1
# ('my', 'return') 1
# ('return', 'go') 1
# ('ceiling', 'and') 1
# ('and', 'beyond,') 1
# ('beyond,', 'which') 1
# ('you', 'spend') 2
# ('spend', 'millions') 2
# ('high', 'level') 1
# ('level', 'on') 1
# ('on', 'lawyers,') 1
# ('lawyers,', 'accountants,') 1
# ('accountants,', 'and') 1
# ('to', 'simplify') 1
# ('simplify', 'them') 1
# ('tremendous', 'level.') 1
# ('The', 'bracket') 1
# ('bracket', 'of') 1
# ('of', '25%') 1
# ('25%', '–') 1
# ('is', 'many') 1
# ('the', 'loopholes') 1
# ('loopholes', 'and') 1
# ('are', 'antiquated') 1
# ('antiquated', 'in') 1
# ('cases.', 'Or') 1
# ('Or', 'are') 1
# ('are', 'put') 1
# ('put', 'there') 1
# ('deductions', 'are') 1
# ('are', 'contributed') 1
# ('to', 'Hillary,') 1
# ('Hillary,', 'they’re') 1
# ('they’re', 'contributing') 1
# ('contributing', 'to') 2
# ('to', 'Bush.') 1
# ('Bush.', 'They’re') 1
# ('They’re', 'contributing') 1
# ('every', 'candidate') 1
# ('candidate', 'but') 1
# ('but', 'Trump.') 1
# ('Trump.', 'Because') 1
# ('want', 'these') 1
# ('these', 'deductions.') 1
# ('deductions.', 'There') 1
# ('we’re', 'reducing') 1
# ('reducing', 'taxes.') 1
# ('taxes.', 'But') 1
# ('But', 'believe') 1
# ('me,', 'there') 1
# ('very', 'upper') 1
# ('upper', 'eschelons') 1
# ('eschelons', 'that') 1
# ('thrilled', 'with') 1
# ('taking', 'away') 1
# ('away', 'deductions') 1
# ('reasons', 'we’re') 1
# ('we’re', 'able') 1
# ('lower', 'it.') 1
# ('A', 'big') 1
# ('big', 'tax') 1
# ('tax', 'reduction,') 1
# ('reduction,', 'including') 1
# ('including', 'for') 1
# ('the', 'upper') 1
# ('upper', 'income.') 1
# ('income.', 'I') 1
# ('well', 'that') 1
# ('that', 'even') 1
# ('be', 'getting') 2
# ('getting', 'certain') 1
# ('certain', 'deductions') 1
# ('which', 'aren’t') 1
# ('aren’t', 'fair') 1
# ('fair', 'for') 1
# ('they’ll', 'end') 1
# ('better.', 'I') 1
# ('sense', 'approach.') 1
# ('approach.', 'You') 1
# ('say', 'supply') 1
# ('supply', 'side.') 1
# ('different', 'names') 1
# ('names', 'given') 1
# ('given', 'out') 1
# ('different', 'kinds') 1
# ('kinds', 'of') 1
# ('of', 'deductions') 1
# ('deductions', 'or') 1
# ('or', 'increases.') 1
# ('increases.', 'I') 1
# ('it’s', 'supply') 1
# ('supply', 'side') 1
# ('sense,', 'well') 1
# ('well', 'thought') 1
# ('thought', 'out') 1
# ('out', 'tax') 1
# ('tax', 'proposal') 1
# ('proposal', 'that’s') 1
# ('to', 'trigger') 1
# ('trigger', 'the') 1
# ('economy,', 'going') 1
# ('everybody', 'go') 1
# ('create', 'tremendous') 1
# ('jobs.', 'One') 1
# ('I’m', 'coupling') 1
# ('coupling', 'this') 1
# ('with', 'is') 1
# ('President,', 'I’m') 1
# ('renegotiate', 'our') 1
# ('deals.', 'Because') 1
# ('not', 'sustainable') 1
# ('sustainable', 'by') 1
# ('country.', 'Not') 1
# ('Not', 'sustainable.') 1
# ('sustainable.', 'We') 1
# ('jobs', 'go') 1
# ('countries.', 'There’s') 1
# ('There’s', 'not') 1
# ('we', 'negotiate') 1
# ('better', 'deal.') 1
# ('deal.', 'Everybody.') 1
# ('lose', 'money') 1
# ('everything.', 'I’m') 1
# ('renegotiate', 'some') 1
# ('military', 'costs.') 1
# ('costs.', 'Because') 1
# ('protect', 'Germany,') 1
# ('Germany,', 'we') 1
# ('protect', 'some') 1
# ('the', 'wealthiest') 1
# ('wealthiest', 'countries') 1
# ('world', '–') 1
# ('–', 'Saudi') 1
# ('Arabia', '–') 1
# ('protect', 'everybody.') 2
# ('get', 'reimbursement.') 1
# ('reimbursement.', 'We') 1
# ('everything.', 'So,') 1
# ('negotiate', 'and') 1
# ('and', 'renegotiate') 1
# ('renegotiate', 'trade') 1
# ('deals,', 'military') 1
# ('military', 'deals,') 1
# ('deals,', 'many') 1
# ('other', 'deals') 1
# ('deals', 'that’s') 1
# ('costs', 'down') 1
# ('down', 'for') 1
# ('for', 'running') 1
# ('country', 'very') 1
# ('very', 'significantly.') 1
# ('significantly.', 'I’m') 1
# ('not', 'showing') 1
# ('in', 'that.') 1
# ('President,', 'those') 1
# ('be', 'massive.') 1
# ('massive.', 'As') 1
# ('example,', 'Saudi') 1
# ('need', 'help.') 1
# ('help.', 'We’re') 1
# ('basis', 'and') 1
# ('trillion.', 'I') 1
# ('say', '$18') 1
# ('trillion', 'for') 1
# ('last', '6,') 1
# ('7', 'months;') 1
# ('months;', 'now') 1
# ('it’s', '$19') 1
# ('up.', 'Well,') 1
# ('Well,', 'no,') 1
# ('no,', 'look.') 1
# ('look.', 'Senator') 1
# ('Senator', '[Marco]') 1
# ('[Marco]', 'Rubio') 1
# ('Rubio', 'is') 1
# ('a', 'lightweight.') 1
# ('lightweight.', 'We') 1
# ('We', 'understand') 1
# ('this.', 'He') 1
# ('wouldn’t', 'know') 1
# ('deal', 'from') 1
# ('other', 'deal') 1
# ('what', 'certain') 1
# ('are', 'trying') 1
# ('last', 'poll.') 1
# ('poll.', 'We') 1
# ('up', 'two') 1
# ('two', 'points') 1
# ('last', 'poll,') 1
# ('poll,', 'and') 1
# ('up.', 'In') 1
# ('the', 'NBC') 1
# ('NBC', 'poll,') 1
# ('from', '26%') 1
# ('26%', 'to') 1
# ('to', '29%.') 1
# ('29%.', 'We’re') 1
# ('up', 'very') 1
# ('strongly', 'in') 1
# ('polls.', 'They') 1
# ('company.', 'You’ll') 1
# ('You’ll', 'see') 1
# ('in', '60') 1
# ('Minutes', 'last') 1
# ('with', 'very') 1
# ('flow.', 'I’m') 1
# ('like', 'Rubio,') 1
# ('Rubio,', 'I') 1
# ('he', 'desperately') 1
# ('desperately', 'needs') 1
# ('money.', 'Ask') 1
# ('Ask', 'the') 2
# ('car', 'dealer') 1
# ('dealer', 'in') 1
# ('Florida.', 'Ask') 1
# ('that', 'support') 1
# ('support', 'him.') 1
# ('like', 'Rubio') 1
# ('others', '–') 1
# ('to', 'single') 1
# ('single', 'him') 1
# ('him', 'out;') 1
# ('out;', 'you’re') 1
# ('you’re', 'singling') 1
# ('singling', 'him') 1
# ('they’re', 'largely') 1
# ('largely', 'controlled') 1
# ('their', 'donors,') 1
# ('donors,', 'the') 1
# ('frankly', 'more') 1
# ('else,', 'the') 1
# ('lobbyists.', 'I’ve') 1
# ('I’ve', 'turned') 1
# ('down', 'millions') 1
# ('from', 'lobbyists') 1
# ('interests', 'because') 1
# ('that', 'seems') 1
# ('be', 'resonating') 1
# ('resonating', 'very') 1
# ('very', 'strongly.') 1
# ('strongly.', 'I') 1
# ('I', 'negotiate.') 1
# ('negotiate.', 'It’s') 1
# ('get', 'bills') 1
# ('bills', 'from') 1
# ('from', 'people;') 1
# ('people;', 'I’ll') 1
# ('I’ll', 'negotiate.') 1
# ('negotiate.', 'Oh,') 1
# ('Oh,', 'is') 1
# ('thing?', 'The') 1
# ('The', 'country') 1
# ('country', 'should') 1
# ('that.', 'Yeah,') 1
# ('I', 'would.') 1
# ('would.', 'I’d') 1
# ('I’d', 'bring') 1
# ('same', 'attitude') 1
# ('attitude', 'to') 1
# ('House.', 'It’s') 1
# ('true.', 'She') 1
# ('says', 'I') 1
# ('a', 'habit') 1
# ('habit', 'when') 1
# ('a', 'bill,') 1
# ('bill,', 'you’d') 1
# ('you’d', 'call') 1
# ('you', 'negotiate.') 1
# ('negotiate.', 'To') 1
# ('compliment.', 'No,') 1
# ('that', 'thinking') 1
# ('thinking', 'to') 1
# ('would', 'bet') 1
# ('could', 'save') 2
# ('save', '20%') 1
# ('20%', 'of') 1
# ('our', 'budget.') 1
# ('budget.', 'I') 1
# ('even', 'save') 1
# ('save', 'more.') 1
# ('tremendous', 'amount.') 1
# ('amount.', 'That') 1
# ('That', 'has') 1
# ('attitude', 'our') 1
# ('country', 'has.') 1
# ('has.', 'You') 1
# ('can’t', 'spend') 1
# ('on', 'doing') 1
# ('for', '$2,000.') 1
# ('$2,000.', 'You') 1
# ('at', 'costs,') 1
# ('costs,', 'we') 1
# ('just', 'spent') 2
# ('spent', '$1') 1
# ('million', 'building') 1
# ('a', 'soccer') 3
# ('soccer', 'field.') 2
# ('field.', 'Okay?') 1
# ('Okay?', 'A') 1
# ('A', 'soccer') 1
# ('soccer', 'field') 1
# ('field', 'for') 1
# ('prisoners', 'that') 1
# ('in', 'Guantanamo.') 1
# ('Guantanamo.', 'Okay?') 1
# ('need', '$1') 1
# ('million', 'for?') 1
# ('for?', 'Level') 1
# ('Level', 'out') 1
# ('the', 'surface,') 1
# ('surface,', 'let') 1
# ('play', '–') 1
# ('play', 'at') 2
# ('all.', 'Okay?') 1
# ('Okay?', 'What') 1
# ('spend', '$1') 2
# ('story', 'today.') 1
# ('today.', '$1') 1
# ('field.', 'How') 1
# ('million', 'doing') 1
# ('soccer', 'field?') 1
# ('field?', 'You') 1
# ('level', 'piece') 1
# ('of', 'land.') 1
# ('land.', 'Throw') 1
# ('Throw', 'them') 1
# ('a', 'ball') 1
# ('ball', 'if') 1
# ('play', 'soccer') 1
# ('soccer', '–') 1
# ('they', 'playing') 1
# ('playing', 'soccer') 1
# ('soccer', 'is') 1
# ('my', 'question.') 1
# ('question.', 'No,') 1
# ('have', 'time.') 2
# ('time.', 'No,') 1
# ('not', 'at') 1
# ('all.', 'We’re') 1
# ('lowering', 'taxes,') 1
# ('taxes,', 'which') 1
# ('which', 'Republicans') 1
# ('Republicans', 'love.') 1
# ('well', 'when') 1
# ('all', 'polls') 1
# ('polls', 'is') 1
# ('the', 'thinking.') 1

# %%
# output = list(ngram_gen)
# output

# %%
# #bigram
# ngram_gen = nltk.bigrams(tokens)
# ngram_gen

# %%
freqd = nltk.FreqDist(ngram_gen)

for k,v in freqd.items():
    print(k,v)
# Out:
# ('the', 'quick', 'fox') 2
# ('quick', 'fox', 'ran') 1
# ('fox', 'ran', 'the') 1
# ('ran', 'the', 'quick') 1

# %%
# def mle_ngram(text, ngram_value):
    
#     if ngram_value == 1:
#

# %%
# def mle_ngram(text, ngram_value):
    
#     if ngram_value == 1:
#         ngram_gen = ngrams(tokens, 1)

# %%
import nltk

SOS = "<s> "
EOS = "</s>"
UNK = "<UNK>"

def add_sentence_tokens(sentences, n):
    """Wrap each sentence in SOS and EOS tokens.
    For n >= 2, n-1 SOS tokens are added, otherwise only one is added.
    Args:
        sentences (list of str): the sentences to wrap.
        n (int): order of the n-gram model which will use these sentences.
    Returns:
        List of sentences with SOS and EOS tokens wrapped around them.
    """
    sos = SOS * (n-1) if n > 1 else SOS
    return ['{}{} {}'.format(sos, s, EOS) for s in sentences]

def replace_singletons(tokens):
    """Replace tokens which appear only once in the corpus with <UNK>.
    
    Args:
        tokens (list of str): the tokens comprising the corpus.
    Returns:
        The same list of tokens with each singleton replaced by <UNK>.
    
    """
    vocab = nltk.FreqDist(tokens)
    return [token if vocab[token] > 1 else UNK for token in tokens]

def preprocess(sentences, n):
    """Add SOS/EOS/UNK tokens to given sentences and tokenize.
    Args:
        sentences (list of str): the sentences to preprocess.
        n (int): order of the n-gram model which will use these sentences.
    Returns:
        The preprocessed sentences, tokenized by words.
    """
    sentences = add_sentence_tokens(sentences, n)
    tokens = ' '.join(sentences).split(' ')
    tokens = replace_singletons(tokens)
    return tokens

# %%
import argparse
from itertools import product
import math
import nltk
from pathlib import Path

# from preprocess import preprocess


def load_data(data_dir):
    """Load train and test corpora from a directory.
    Directory must contain two files: train.txt and test.txt.
    Newlines will be stripped out. 
    Args:
        data_dir (Path) -- pathlib.Path of the directory to use. 
    Returns:
        The train and test sets, as lists of sentences.
    """
    train_path = data_dir.joinpath('train.txt').absolute().as_posix()
    test_path  = data_dir.joinpath('test.txt').absolute().as_posix()

    with open(train_path, 'r') as f:
        train = [l.strip() for l in f.readlines()]
    with open(test_path, 'r') as f:
        test = [l.strip() for l in f.readlines()]
    return train, test


class LanguageModel(object):
    """An n-gram language model trained on a given corpus.
    
    For a given n and given training corpus, constructs an n-gram language
    model for the corpus by:
    1. preprocessing the corpus (adding SOS/EOS/UNK tokens)
    2. calculating (smoothed) probabilities for each n-gram
    Also contains methods for calculating the perplexity of the model
    against another corpus, and for generating sentences.
    Args:
        train_data (list of str): list of sentences comprising the training corpus.
        n (int): the order of language model to build (i.e. 1 for unigram, 2 for bigram, etc.).
        laplace (int): lambda multiplier to use for laplace smoothing (default 1 for add-1 smoothing).
    """

    def __init__(self, train_data, n, laplace=1):
        self.n = n
        self.laplace = laplace
        self.tokens = preprocess(train_data, n)
        self.vocab  = nltk.FreqDist(self.tokens)
        self.model  = self._create_model()
        self.masks  = list(reversed(list(product((0,1), repeat=n))))

    def _smooth(self):
        """Apply Laplace smoothing to n-gram frequency distribution.
        
        Here, n_grams refers to the n-grams of the tokens in the training corpus,
        while m_grams refers to the first (n-1) tokens of each n-gram.
        Returns:
            dict: Mapping of each n-gram (tuple of str) to its Laplace-smoothed 
            probability (float).
        """
        vocab_size = len(self.vocab)

        n_grams = nltk.ngrams(self.tokens, self.n)
        n_vocab = nltk.FreqDist(n_grams)

        m_grams = nltk.ngrams(self.tokens, self.n-1)
        m_vocab = nltk.FreqDist(m_grams)

        def smoothed_count(n_gram, n_count):
            m_gram = n_gram[:-1]
            m_count = m_vocab[m_gram]
            return (n_count + self.laplace) / (m_count + self.laplace * vocab_size)

        return { n_gram: smoothed_count(n_gram, count) for n_gram, count in n_vocab.items() }

    def _create_model(self):
        """Create a probability distribution for the vocabulary of the training corpus.
        
        If building a unigram model, the probabilities are simple relative frequencies
        of each token with the entire corpus.
        Otherwise, the probabilities are Laplace-smoothed relative frequencies.
        Returns:
            A dict mapping each n-gram (tuple of str) to its probability (float).
        """
        if self.n == 1:
            num_tokens = len(self.tokens)
            return { (unigram,): count / num_tokens for unigram, count in self.vocab.items() }
        else:
            return self._smooth()

    def _convert_oov(self, ngram):
        """Convert, if necessary, a given n-gram to one which is known by the model.
        Starting with the unmodified ngram, check each possible permutation of the n-gram
        with each index of the n-gram containing either the original token or <UNK>. Stop
        when the model contains an entry for that permutation.
        This is achieved by creating a 'bitmask' for the n-gram tuple, and swapping out
        each flagged token for <UNK>. Thus, in the worst case, this function checks 2^n
        possible n-grams before returning.
        Returns:
            The n-gram with <UNK> tokens in certain positions such that the model
            contains an entry for it.
        """
        mask = lambda ngram, bitmask: tuple((token if flag == 1 else "<UNK>" for token,flag in zip(ngram, bitmask)))

        ngram = (ngram,) if type(ngram) is str else ngram
        for possible_known in [mask(ngram, bitmask) for bitmask in self.masks]:
            if possible_known in self.model:
                return possible_known

    def perplexity(self, test_data):
        """Calculate the perplexity of the model against a given test corpus.
        
        Args:
            test_data (list of str): sentences comprising the training corpus.
        Returns:
            The perplexity of the model as a float.
        
        """
        test_tokens = preprocess(test_data, self.n)
        test_ngrams = nltk.ngrams(test_tokens, self.n)
        N = len(test_tokens)

        known_ngrams  = (self._convert_oov(ngram) for ngram in test_ngrams)
        probabilities = [self.model[ngram] for ngram in known_ngrams]

        return math.exp((-1/N) * sum(map(math.log, probabilities)))

    def _best_candidate(self, prev, i, without=[]):
        """Choose the most likely next token given the previous (n-1) tokens.
        If selecting the first word of the sentence (after the SOS tokens),
        the i'th best candidate will be selected, to create variety.
        If no candidates are found, the EOS token is returned with probability 1.
        Args:
            prev (tuple of str): the previous n-1 tokens of the sentence.
            i (int): which candidate to select if not the most probable one.
            without (list of str): tokens to exclude from the candidates list.
        Returns:
            A tuple with the next most probable token and its corresponding probability.
        """
        blacklist  = ["<UNK>"] + without
        candidates = ((ngram[-1],prob) for ngram,prob in self.model.items() if ngram[:-1]==prev)
        candidates = filter(lambda candidate: candidate[0] not in blacklist, candidates)
        candidates = sorted(candidates, key=lambda candidate: candidate[1], reverse=True)
        if len(candidates) == 0:
            return ("</s>", 1)
        else:
            return candidates[0 if prev != () and prev[-1] != "<s>" else i]
     
    def generate_sentences(self, num, min_len=12, max_len=24):
        """Generate num random sentences using the language model.
        Sentences always begin with the SOS token and end with the EOS token.
        While unigram model sentences will only exclude the UNK token, n>1 models
        will also exclude all other words already in the sentence.
        Args:
            num (int): the number of sentences to generate.
            min_len (int): minimum allowed sentence length.
            max_len (int): maximum allowed sentence length.
        Yields:
            A tuple with the generated sentence and the combined probability
            (in log-space) of all of its n-grams.
        """
        for i in range(num):
            sent, prob = ["<s>"] * max(1, self.n-1), 1
            while sent[-1] != "</s>":
                prev = () if self.n == 1 else tuple(sent[-(self.n-1):])
                blacklist = sent + (["</s>"] if len(sent) < min_len else [])
                next_token, next_prob = self._best_candidate(prev, i, without=blacklist)
                sent.append(next_token)
                prob *= next_prob
                
                if len(sent) >= max_len:
                    sent.append("</s>")

            yield ' '.join(sent), -1/math.log(prob)

# %%
if __name__ == '__main__':
    parser = argparse.ArgumentParser("N-gram Language Model")
    parser.add_argument('--data', type=str, required=True,
            help='Location of the data directory containing train.txt and test.txt')
    parser.add_argument('--n', type=int, required=True,
            help='Order of N-gram model to create (i.e. 1 for unigram, 2 for bigram, etc.)')
    parser.add_argument('--laplace', type=float, default=0.01,
            help='Lambda parameter for Laplace smoothing (default is 0.01 -- use 1 for add-1 smoothing)')
    parser.add_argument('--num', type=int, default=10,
            help='Number of sentences to generate (default 10)')
    args = parser.parse_args()

    # Load and prepare train/test data
#     data_path = Path(args.data)
#     train, test = load_data(data_path)

    print("Loading {}-gram model...".format(args.n))
    lm = LanguageModel(train, args.n, laplace=args.laplace)
    print("Vocabulary size: {}".format(len(lm.vocab)))

    print("Generating sentences...")
    for sentence, prob in lm.generate_sentences(args.num):
        print("{} ({:.5f})".format(sentence, prob))

    perplexity = lm.perplexity(test)
    print("Model perplexity: {:.3f}".format(perplexity))
    print("")
# Out:
# usage: N-gram Language Model [-h] --data DATA --n N [--laplace LAPLACE]
#                              [--num NUM]
# N-gram Language Model: error: the following arguments are required: --data, --n
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /home/rauswarn/anaconda2/envs/nlp/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
